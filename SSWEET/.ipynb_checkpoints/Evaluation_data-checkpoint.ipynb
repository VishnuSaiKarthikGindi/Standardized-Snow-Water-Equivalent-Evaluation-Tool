# %%
# Import packages
# Dataframe Packages
import numpy as np
import xarray as xr
import pandas as pd

# Vector Packages
import geopandas as gpd
import shapely
from shapely.geometry import Point, Polygon

# Raster Packages
import rioxarray as rxr
from rioxarray.merge import merge_arrays
import rasterstats as rs
import gdal

# Data Access Packages
import earthaccess as ea
import h5py
import pickle
from tensorflow.keras.models import load_model

# General Packages
import os
import re
import shutil
from datetime import datetime
import glob
from pprint import pprint
from typing import Union
from pathlib import Path
from tqdm import tqdm
import time
import requests

# %%
import NSIDC_Data

class ASODataTool:
    def __init__(self, short_name, version, polygon='', filename_filter=''):
        self.short_name = short_name
        self.version = version
        self.polygon = polygon
        self.filename_filter = filename_filter
        self.url_list = []
        self.CMR_URL = 'https://cmr.earthdata.nasa.gov'
        self.CMR_PAGE_SIZE = 2000
        self.CMR_FILE_URL = ('{0}/search/granules.json?provider=NSIDC_ECS'
                             '&sort_key[]=start_date&sort_key[]=producer_granule_id'
                             '&scroll=true&page_size={1}'.format(self.CMR_URL, self.CMR_PAGE_SIZE))

    def cmr_search(self, time_start, time_end, bounding_box):
        try:
            if not self.url_list:
                self.url_list = NSIDC_Data.cmr_search(
                    self.short_name, self.version, time_start, time_end,
                    bounding_box=self.bounding_box, polygon=self.polygon,
                    filename_filter=self.filename_filter, quiet=False)
            return self.url_list
        except KeyboardInterrupt:
            quit()

    def cmr_download(self, directory):
        if not os.path.exists(directory):
            os.makedirs(directory, exist_ok=True)

        NSIDC_Data.cmr_download(self.url_list, directory, False)

    @staticmethod
    def get_bounding_box(region):
        regions = pd.read_pickle("C:\\Users\\VISH NU\\National_snow_model\\National-Snow-Model\\Data\\Processed\\RegionVal.pkl")
        superset = []

        superset.append(regions[region])
        superset = pd.concat(superset)
        superset = gpd.GeoDataFrame(superset, geometry=gpd.points_from_xy(superset.Long, superset.Lat, crs="EPSG:4326"))
        bounding_box = list(superset.total_bounds)

        return f"{bounding_box[0]},{bounding_box[1]},{bounding_box[2]},{bounding_box[3]}"

class ASODownload(ASODataTool):
    def __init__(self, short_name, version, polygon='', filename_filter=''):
        super().__init__(short_name, version, polygon, filename_filter)
        self.region_list =    [ 'N_Sierras',
                                'S_Sierras',
                                'Greater_Yellowstone',
                                'N_Co_Rockies',
                                'SW_Mont',
                                'SW_Co_Rockies',
                                'GBasin',
                                'N_Wasatch',
                                'N_Cascade',
                                'S_Wasatch',
                                'SW_Mtns',
                                'E_WA_N_Id_W_Mont',
                                'S_Wyoming',
                                'SE_Co_Rockies',
                                'Sawtooth',
                                'Ca_Coast',
                                'E_Or',
                                'N_Yellowstone',
                                'S_Cascade',
                                'Wa_Coast',
                                'Greater_Glacier',
                                'Or_Coast'  ]

    def select_region(self):
        print("Select a region by entering its index:")
        for i, region in enumerate(self.region_list, start=1):
            print(f"{i}. {region}")

        try:
            user_input = int(input("Enter the index of the region: "))
            if 1 <= user_input <= len(self.region_list):
                selected_region = self.region_list[user_input - 1]
                self.bounding_box = self.get_bounding_box(selected_region)
                print(f"You selected: {selected_region}")
                print(f"Bounding Box: {self.bounding_box}")
            else:
                print("Invalid index. Please select a valid index.")
        except ValueError:
            print("Invalid input. Please enter a valid index.")
            
if __name__ == "__main__":
    short_name = 'ASO_50M_SWE'
    version = '1'

    data_tool = ASODownload(short_name, version)
    time_start = '2013-04-02T00:00:00Z'
    time_end = '2019-07-19T23:59:59Z'
    
    selected_region = data_tool.select_region()  # Call select_region on the instance
    directory = "SWE_Data"

    print(f"Fetching file URLs in progress for {selected_region} from {time_start} to {time_end}")
    url_list = data_tool.cmr_search(time_start, time_end, data_tool.bounding_box)
    data_tool.cmr_download(directory)
# Out:
# Select a region by entering its index:
# 1. N_Sierras
# 2. S_Sierras
# 3. Greater_Yellowstone
# 4. N_Co_Rockies
# 5. SW_Mont
# 6. SW_Co_Rockies
# 7. GBasin
# 8. N_Wasatch
# 9. N_Cascade
# 10. S_Wasatch
# 11. SW_Mtns
# 12. E_WA_N_Id_W_Mont
# 13. S_Wyoming
# 14. SE_Co_Rockies
# 15. Sawtooth
# 16. Ca_Coast
# 17. E_Or
# 18. N_Yellowstone
# 19. S_Cascade
# 20. Wa_Coast
# 21. Greater_Glacier
# 22. Or_Coast
# Enter the index of the region: 2
# You selected: S_Sierras
# Bounding Box: -120.3763448720203,36.29256774541929,-118.292253412863,38.994985247736324
# Fetching file URLs in progress for None from 2013-04-02T00:00:00Z to 2019-07-19T23:59:59Z
# Querying for data:
# 	https://cmr.earthdata.nasa.gov/search/granules.json?provider=NSIDC_ECS&sort_key[]=start_date&sort_key[]=producer_granule_id&scroll=true&page_size=2000&short_name=ASO_50M_SWE&version=001&version=01&version=1&temporal[]=2013-04-02T00:00:00Z,2019-07-19T23:59:59Z&bounding_box=-120.3763448720203,36.29256774541929,-118.292253412863,38.994985247736324
#
# Found 94 matches.
# ['https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2013.04.03/ASO_50M_SWE_USCATB_20130403.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2013.04.03/ASO_50M_SWE_USCATB_20130403.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2013.04.29/ASO_50M_SWE_USCATB_20130429.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2013.04.29/ASO_50M_SWE_USCATB_20130429.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2013.05.03/ASO_50M_SWE_USCATB_20130503.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2013.05.03/ASO_50M_SWE_USCATB_20130503.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2013.05.25/ASO_50M_SWE_USCATB_20130525.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2013.05.25/ASO_50M_SWE_USCATB_20130525.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2013.06.01/ASO_50M_SWE_USCATB_20130601.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2013.06.01/ASO_50M_SWE_USCATB_20130601.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2013.06.08/ASO_50M_SWE_USCATB_20130608.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2013.06.08/ASO_50M_SWE_USCATB_20130608.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.03.26/ASO_50M_SWE_USCATB_20160326.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.03.26/ASO_50M_SWE_USCATB_20160326.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.04.01/ASO_50M_SWE_USCACE_20160401.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.04.01/ASO_50M_SWE_USCACE_20160401.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.04.01/ASO_50M_SWE_USCATB_20160401.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.04.01/ASO_50M_SWE_USCATB_20160401.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.04.07/ASO_50M_SWE_USCACE_20160407.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.04.07/ASO_50M_SWE_USCACE_20160407.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.04.07/ASO_50M_SWE_USCATB_20160407.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.04.07/ASO_50M_SWE_USCATB_20160407.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.04.16/ASO_50M_SWE_USCACE_20160416.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.04.16/ASO_50M_SWE_USCACE_20160416.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.04.16/ASO_50M_SWE_USCATB_20160416.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.04.16/ASO_50M_SWE_USCATB_20160416.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.04.26/ASO_50M_SWE_USCACE_20160426.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.04.26/ASO_50M_SWE_USCACE_20160426.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.04.26/ASO_50M_SWE_USCATB_20160426.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.04.26/ASO_50M_SWE_USCATB_20160426.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.05.09/ASO_50M_SWE_USCACE_20160509.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.05.09/ASO_50M_SWE_USCACE_20160509.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.05.09/ASO_50M_SWE_USCALB_20160509.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.05.09/ASO_50M_SWE_USCALB_20160509.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.05.09/ASO_50M_SWE_USCATB_20160509.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.05.09/ASO_50M_SWE_USCATB_20160509.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.05.27/ASO_50M_SWE_USCATB_20160527.tif', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.05.27/ASO_50M_SWE_USCATB_20160527.tif.xml', 'https://n5eil01u.ecs.nsidc.org/DP1/ASO/ASO_50M_SWE.001/2016.06.07/ASO_50M_SWE_USCALB ...
# Downloading 188 files to SWE_Data...
# Earthdata Login Username: vishnugindi
# Earthdata Login Password: ········
# dmlzaG51Z2luZGk6UHJvY2Vzc2luZzEh
# 001/188: SWE_Data\ASO_50M_SWE_USCATB_20130403.tif
#   [============                                                ]  20%  2.1MB/s    [========================                                    ]  40%  1.9MB/s    [====================================                        ]  60%  1.9MB/s    [================================================            ]  80%  2.4MB/s    [============================================================] 100%  2.9MB/s
# 002/188: SWE_Data\ASO_50M_SWE_USCATB_20130403.tif.xml
#   [============================================================] 100%  210.1kB/s
# 003/188: SWE_Data\ASO_50M_SWE_USCATB_20130429.tif
#   [============                                                ]  20%  2.8MB/s    [========================                                    ]  40%  2.5MB/s    [====================================                        ]  60%  1.7MB/s    [================================================            ]  80%  1.5MB/s    [============================================================] 100%  1.8MB/s
# 004/188: SWE_Data\ASO_50M_SWE_USCATB_20130429.tif.xml
#   [============================================================] 100%
# 005/188: SWE_Data\ASO_50M_SWE_USCATB_20130503.tif
#   [============                                                ]  20%  2.4MB/s    [========================                                    ]  40%  3.9MB/s    [====================================                        ]  60%  4.8MB/s    [================================================            ]  80%  5.8MB/s    [============================================================] 100%  7.2MB/s
# 006/188: SWE_Data\ASO_50M_SWE_USCATB_20130503.tif.xml
#   [============================================================] 100%
# 007/188: SWE_Data\ASO_50M_SWE_USCATB_20130525.tif
#   [============                                                ]  20%  2.6MB/s    [========================                                    ]  40%  4.2MB/s    [====================================                        ]  60%  5.2MB/s    [================================================            ]  80%  6.2MB/s    [============================================================] 100%  7.7MB/s
# 008/188: SWE_Data\ASO_50M_SWE_USCATB_20130525.tif.xml
#   [============================================================] 100%  2.6MB/s
# 009/188: SWE_Data\ASO_50M_SWE_USCATB_20130601.tif
#   [============                                                ]  20%  1.1MB/s    [========================                                    ]  40%  1.8MB/s    [====================================                        ]  60%  2.2MB/s    [================================================            ]  80%  2.6MB/s    [============================================================] 100%  3.2MB/s
# 010/188: SWE_Data\ASO_50M_SWE_USCATB_20130601.tif.xml
#   [============================================================] 100%  1.6MB/s
# 011/188: SWE_Data\ASO_50M_SWE_USCATB_20130608.tif
#   [============                                                ]  20%  2.8MB/s    [========================                                    ]  40%  4.3MB/s    [====================================                        ]  60%  5.3MB/s    [================================================            ]  80%  6.0MB/s    [============================================================] 100%  7.3MB/s
# 012/188: SWE_Data\ASO_50M_SWE_USCATB_20130608.tif.xml
#   [============================================================] 100%
# 013/188: SWE_Data\ASO_50M_SWE_USCATB_20160326.tif
#   [==========                                                  ]  17%  2.4MB/s    [====================                                        ]  33%  3.7MB/s    [==============================                              ]  50%  4.5MB/s    [========================================                    ]  67%  5.2MB/s    [==================================================          ]  83%  5.6MB/s    [============================================================] 100%  6.3MB/s
# 014/188: SWE_Data\ASO_50M_SWE_USCATB_20160326.tif.xml
#   [============================================================] 100%
# 015/188: SWE_Data\ASO_50M_SWE_USCACE_20160401.tif
#   [==========                                                  ]  17%  2.6MB/s    [====================                                        ]  33%  3.3MB/s    [==============================                              ]  50%  4.0MB/s    [========================================                    ]  67%  4.5MB/s    [==================================================          ]  83%  4.8MB/s    [============================================================] 100%  5.4MB/s
# 016/188: SWE_Data\ASO_50M_SWE_USCACE_20160401.tif.xml
#   [============================================================] 100%  305.5kB/s
# 017/188: SWE_Data\ASO_50M_SWE_USCATB_20160401.tif
#   [==========                                                  ]  17%  2.8MB/s    [====================                                        ]  33%  3.9MB/s    [==============================                              ]  50%  4.5MB/s    [========================================                    ]  67%  5.0MB/s    [==================================================          ]  83%  5.3MB/s    [============================================================] 100%  5.9MB/s
# 018/188: SWE_Data\ASO_50M_SWE_USCATB_20160401.tif.xml
#   [============================================================] 100%
# 019/188: SWE_Data\ASO_50M_SWE_USCACE_20160407.tif
#   [==========                                                  ]  17%  2.2MB/s    [====================                                        ]  33%  3.3MB/s    [==============================                              ]  50%  4.2MB/s    [========================================                    ]  67%  4.9MB/s    [==================================================          ]  83%  5.4MB/s    [============================================================] 100%  6.2MB/s
# 020/188: SWE_Data\ASO_50M_SWE_USCACE_20160407.tif.xml
#   [============================================================] 100%  1.6MB/s
# 021/188: SWE_Data\ASO_50M_SWE_USCATB_20160407.tif
#   [==========                                                  ]  17%  2.9MB/s    [====================                                        ]  33%  4.1MB/s    [==============================                              ]  50%  5.1MB/s    [========================================                    ]  67%  5.8MB/s    [==================================================          ]  83%  6.5MB/s    [============================================================] 100%  7.3MB/s
# 022/188: SWE_Data\ASO_50M_SWE_USCATB_20160407.tif.xml
#   [============================================================] 100%  1.6MB/s
# 023/188: SWE_Data\ASO_50M_SWE_USCACE_20160416.tif
#   [==========                                                  ]  17%  2.5MB/s    [====================                                        ]  33%  3.9MB/s    [==============================                              ]  50%  5.1MB/s    [========================================                    ]  67%  5.2MB/s    [==================================================          ]  83%  5.7MB/s    [============================================================] 100%  6.4MB/s
# 024/188: SWE_Data\ASO_50M_SWE_USCACE_20160416.tif.xml
#   [============================================================] 100%
# 025/188: SWE_Data\ASO_50M_SWE_USCATB_20160416.tif
#   [==========                                                  ]  17%  2.9MB/s    [====================                                        ]  33%  3.4MB/s    [==============================                              ]  50%  4.7MB/s    [========================================                    ]  67%  4.4MB/s    [==================================================          ]  83%  4.9MB/s    [============================================================] 100%  5.5MB/s
# 026/188: SWE_Data\ASO_50M_SWE_USCATB_20160416.tif.xml
#   [============================================================] 100%
# 027/188: SWE_Data\ASO_50M_SWE_USCACE_20160426.tif
#   [==========                                                  ]  17%  1.9MB/s    [====================                                        ]  33%  2.0MB/s    [==============================                              ]  50%  2.1MB/s    [========================================                    ]  67%  2.2MB/s    [==================================================          ]  83%  2.3MB/s    [============================================================] 100%  2.2MB/s
# 028/188: SWE_Data\ASO_50M_SWE_USCACE_20160426.tif.xml
#   [============================================================] 100%
# 029/188: SWE_Data\ASO_50M_SWE_USCATB_20160426.tif
#   [==========                                                  ]  17%  2.7MB/s    [====================                                        ]  33%  4.1MB/s    [==============================                              ]  50%  5.0MB/s    [========================================                    ]  67%  5.6MB/s    [==================================================          ]  83%  5.3MB/s    [============================================================] 100%  6.2MB/s
# 030/188: SWE_Data\ASO_50M_SWE_USCATB_20160426.tif.xml
#   [============================================================] 100%  293.3kB/s
# 031/188: SWE_Data\ASO_50M_SWE_USCACE_20160509.tif
#   [==========                                                  ]  17%  2.2MB/s    [====================                                        ]  33%  3.1MB/s    [==============================                              ]  50%  3.3MB/s    [========================================                    ]  67%  3.6MB/s    [==================================================          ]  83%  4.0MB/s    [============================================================] 100%  4.5MB/s
# 032/188: SWE_Data\ASO_50M_SWE_USCACE_20160509.tif.xml
#   [============================================================] 100%
# 033/188: SWE_Data\ASO_50M_SWE_USCALB_20160509.tif
#   [============================================================] 100%  1.1MB/s
# 034/188: SWE_Data\ASO_50M_SWE_USCALB_20160509.tif.xml
#   [============================================================] 100%  652.4kB/s
# 035/188: SWE_Data\ASO_50M_SWE_USCATB_20160509.tif
#   [==========                                                  ]  17%  2.9MB/s    [====================                                        ]  33%  4.8MB/s    [==============================                              ]  50%  6.0MB/s    [========================================                    ]  67%  7.0MB/s    [==================================================          ]  83%  7.8MB/s    [============================================================] 100%  8.9MB/s
# 036/188: SWE_Data\ASO_50M_SWE_USCATB_20160509.tif.xml
#   [============================================================] 100%
# 037/188: SWE_Data\ASO_50M_SWE_USCATB_20160527.tif
#   [============                                                ]  20%  2.5MB/s    [========================                                    ]  40%  3.9MB/s    [====================================                        ]  60%  5.1MB/s    [================================================            ]  80%  6.0MB/s    [============================================================] 100%  7.3MB/s
# 038/188: SWE_Data\ASO_50M_SWE_USCATB_20160527.tif.xml
#   [============================================================] 100%
# 039/188: SWE_Data\ASO_50M_SWE_USCALB_20160607.tif
#   [============================================================] 100%  1.0MB/s
# 040/188: SWE_Data\ASO_50M_SWE_USCALB_20160607.tif.xml
#   [============================================================] 100%
# 041/188: SWE_Data\ASO_50M_SWE_USCALB_20160614.tif
#   [============================================================] 100%  1.0MB/s
# 042/188: SWE_Data\ASO_50M_SWE_USCALB_20160614.tif.xml
#   [============================================================] 100%  260.2kB/s
# 043/188: SWE_Data\ASO_50M_SWE_USCALB_20160621.tif
#   [============================================================] 100%  380.9kB/s
# 044/188: SWE_Data\ASO_50M_SWE_USCALB_20160621.tif.xml
#   [============================================================] 100%
# 045/188: SWE_Data\ASO_50M_SWE_USCALB_20160626.tif
#   [============================================================] 100%  1.1MB/s
# 046/188: SWE_Data\ASO_50M_SWE_USCALB_20160626.tif.xml
#   [============================================================] 100%
# 047/188: SWE_Data\ASO_50M_SWE_USCATB_20160708.tif
#   [============                                                ]  20%  2.8MB/s    [========================                                    ]  40%  4.4MB/s    [====================================                        ]  60%  5.8MB/s    [================================================            ]  80%  6.8MB/s    [============================================================] 100%  8.2MB/s
# 048/188: SWE_Data\ASO_50M_SWE_USCATB_20160708.tif.xml
#   [============================================================] 100%
# 049/188: SWE_Data\ASO_50M_SWE_USCALB_20170128.tif
#   [============================================================] 100%  1.0MB/s
# 050/188: SWE_Data\ASO_50M_SWE_USCALB_20170128.tif.xml
#   [============================================================] 100%  914.3kB/s
# 051/188: SWE_Data\ASO_50M_SWE_USCACE_20170129.tif
#   [==========                                                  ]  17%  2.6MB/s    [====================                                        ]  33%  4.2MB/s    [==============================                              ]  50%  5.2MB/s    [========================================                    ]  67%  6.0MB/s    [==================================================          ]  83%  6.0MB/s    [============================================================] 100%  6.5MB/s
# 052/188: SWE_Data\ASO_50M_SWE_USCACE_20170129.tif.xml
#   [============================================================] 100%
# 053/188: SWE_Data\ASO_50M_SWE_USCATB_20170129.tif
#   [==========                                                  ]  17%  2.5MB/s    [====================                                        ]  33%  4.0MB/s    [==============================                              ]  50%  5.1MB/s    [========================================                    ]  67%  6.2MB/s    [==================================================          ]  83%  7.0MB/s    [============================================================] 100%  7.4MB/s
# 054/188: SWE_Data\ASO_50M_SWE_USCATB_20170129.tif.xml
#   [============================================================] 100%
# 055/188: SWE_Data\ASO_50M_SWE_USCATE_20170129.tif
#   [====================                                        ]  33%  1.8MB/s    [========================================                    ]  67%  2.9MB/s    [============================================================] 100%  3.9MB/s
# 056/188: SWE_Data\ASO_50M_SWE_USCATE_20170129.tif.xml
#   [============================================================] 100%  246.3kB/s
# 057/188: SWE_Data\ASO_50M_SWE_USCACE_20170717.tif
#   [==========                                                  ]  17%  2.5MB/s    [====================                                        ]  33%  3.8MB/s    [==============================                              ]  50%  4.8MB/s    [========================================                    ]  67%  5.4MB/s    [==================================================          ]  83%  5.9MB/s    [============================================================] 100%  6.6MB/s
# 058/188: SWE_Data\ASO_50M_SWE_USCACE_20170717.tif.xml
#   [============================================================] 100%  4.1MB/s
# 059/188: SWE_Data\ASO_50M_SWE_USCALV_20170717.tif
#   [============================================================] 100%  1.4MB/s
# 060/188: SWE_Data\ASO_50M_SWE_USCALV_20170717.tif.xml
#   [============================================================] 100%  3.3MB/s
# 061/188: SWE_Data\ASO_50M_SWE_USCARC_20170717.tif
#   [============================================================] 100%  1.5MB/s
# 062/188: SWE_Data\ASO_50M_SWE_USCARC_20170717.tif.xml
#   [============================================================] 100%  5.1MB/s
# 063/188: SWE_Data\ASO_50M_SWE_USCATB_20170717.tif
#   [==========                                                  ]  17%  2.8MB/s    [====================                                        ]  33%  4.5MB/s    [==============================                              ]  50%  4.5MB/s    [========================================                    ]  67%  5.5MB/s    [==================================================          ]  83%  5.9MB/s    [============================================================] 100%  6.6MB/s
# 064/188: SWE_Data\ASO_50M_SWE_USCATB_20170717.tif.xml
#   [============================================================] 100%
# 065/188: SWE_Data\ASO_50M_SWE_USCALB_20170718.tif
#   [============================================================] 100%  1.2MB/s
# 066/188: SWE_Data\ASO_50M_SWE_USCALB_20170718.tif.xml
#   [============================================================] 100%
# 067/188: SWE_Data\ASO_50M_SWE_USCASF_20170718.tif
#   [====                                                        ]   7%  2.3MB/s    [========                                                    ]  13%  3.5MB/s    [============                                                ]  20%  4.2MB/s    [================                                            ]  27%  4.7MB/s    [====================                                        ]  33%  5.0MB/s    [========================                                    ]  40%  5.2MB/s    [============================                                ]  47%  5.3MB/s    [================================                            ]  53%  5.2MB/s    [====================================                        ]  60%  4.9MB/s    [========================================                    ]  67%  4.9MB/s    [============================================                ]  73%  5.0MB/s    [================================================            ]  80%  5.1MB/s    [====================================================        ]  87%  5.1MB/s    [========================================================    ]  93%  5.0MB/s    [============================================================] 100%  4.9MB/s
# 068/188: SWE_Data\ASO_50M_SWE_USCASF_20170718.tif.xml
#   [============================================================] 100%
# 069/188: SWE_Data\ASO_50M_SWE_USCASJ_20170719.tif
#   [====                                                        ]   7%  2.1MB/s    [========                                                    ]  13%  3.2MB/s    [============                                                ]  20%  3.8MB/s    [================                                            ]  27%  4.0MB/s    [====================                                        ]  33%  4.0MB/s    [========================                                    ]  40%  4.1MB/s    [============================                                ]  47%  4.3MB/s    [================================                            ]  53%  4.4MB/s    [====================================                        ]  60%  4.4MB/s    [========================================                    ]  67%  4.3MB/s    [============================================                ]  73%  4.2MB/s    [================================================            ]  80%  4.1MB/s    [====================================================        ]  87%  4.1MB/s    [========================================================    ]  93%  4.1MB/s    [============================================================] 100%  4.1MB/s
# 070/188: SWE_Data\ASO_50M_SWE_USCASJ_20170719.tif.xml
#   [============================================================] 100%  233.2kB/s
# 071/188: SWE_Data\ASO_50M_SWE_USCACE_20170727.tif
#   [==========                                                  ]  17%  2.8MB/s    [====================                                        ]  33%  4.5MB/s    [==============================                              ]  50%  5.9MB/s    [========================================                    ]  67%  6.9MB/s    [==================================================          ]  83%  7.7MB/s    [============================================================] 100%  8.8MB/s
# 072/188: SWE_Data\ASO_50M_SWE_USCACE_20170727.tif.xml
#   [============================================================] 100%
# 073/188: SWE_Data\ASO_50M_SWE_USCATB_20170727.tif
#   [==========                                                  ]  17%  2.6MB/s    [====================                                        ]  33%  3.9MB/s    [==============================                              ]  50%  5.2MB/s    [========================================                    ]  67%  6.0MB/s    [==================================================          ]  83%  6.8MB/s    [============================================================] 100%  7.7MB/s
# 074/188: SWE_Data\ASO_50M_SWE_USCATB_20170727.tif.xml
#   [============================================================] 100%
# 075/188: SWE_Data\ASO_50M_SWE_USCALB_20170815.tif
#   [============================================================] 100%  1.0MB/s
# 076/188: SWE_Data\ASO_50M_SWE_USCALB_20170815.tif.xml
#   [============================================================] 100%
# 077/188: SWE_Data\ASO_50M_SWE_USCASJ_20170815.tif
#   [====                                                        ]   7%  2.8MB/s    [========                                                    ]  13%  4.3MB/s    [============                                                ]  20%  5.5MB/s    [================                                            ]  27%  6.3MB/s    [====================                                        ]  33%  6.5MB/s    [========================                                    ]  40%  6.6MB/s    [============================                                ]  47%  6.8MB/s    [================================                            ]  53%  7.1MB/s    [====================================                        ]  60%  7.0MB/s    [========================================                    ]  67%  6.9MB/s    [============================================                ]  73%  6.7MB/s    [================================================            ]  80%  6.5MB/s    [====================================================        ]  87%  6.5MB/s    [========================================================    ]  93%  6.5MB/s    [============================================================] 100%  6.7MB/s
# 078/188: SWE_Data\ASO_50M_SWE_USCASJ_20170815.tif.xml
#   [============================================================] 100%  1.1MB/s
# 079/188: SWE_Data\ASO_50M_SWE_USCACE_20170816.tif
#   [==========                                                  ]  17%  2.7MB/s    [====================                                        ]  33%  4.3MB/s    [==============================                              ]  50%  5.4MB/s    [========================================                    ]  67%  6.3MB/s    [==================================================          ]  83%  6.9MB/s    [============================================================] 100%  7.7MB/s
# 080/188: SWE_Data\ASO_50M_SWE_USCACE_20170816.tif.xml
#   [============================================================] 100%
# 081/188: SWE_Data\ASO_50M_SWE_USCATB_20170816.tif
#   [==========                                                  ]  17%  2.5MB/s    [====================                                        ]  33%  3.3MB/s    [==============================                              ]  50%  3.7MB/s    [========================================                    ]  67%  4.1MB/s    [==================================================          ]  83%  4.4MB/s    [============================================================] 100%  5.0MB/s
# 082/188: SWE_Data\ASO_50M_SWE_USCATB_20170816.tif.xml
#   [============================================================] 100%
# 083/188: SWE_Data\ASO_50M_SWE_USCASJ_20180304.tif
#   [====                                                        ]   7%  2.8MB/s    [========                                                    ]  13%  4.6MB/s    [============                                                ]  20%  5.7MB/s    [================                                            ]  27%  6.7MB/s    [====================                                        ]  33%  7.5MB/s    [========================                                    ]  40%  8.2MB/s    [============================                                ]  47%  8.8MB/s    [================================                            ]  53%  9.4MB/s    [====================================                        ]  60%  8.5MB/s    [========================================                    ]  67%  8.9MB/s    [============================================                ]  73%  9.0MB/s    [================================================            ]  80%  9.3MB/s    [====================================================        ]  87%  9.3MB/s    [========================================================    ]  93%  9.7MB/s    [============================================================] 100%  9.9MB/s
# 084/188: SWE_Data\ASO_50M_SWE_USCASJ_20180304.tif.xml
#   [============================================================] 100%
# 085/188: SWE_Data\ASO_50M_SWE_USCALB_20180422.tif
#   [============================================================] 100%  181.3kB/s
# 086/188: SWE_Data\ASO_50M_SWE_USCALB_20180422.tif.xml
#   [============================================================] 100%
# 087/188: SWE_Data\ASO_50M_SWE_USCASJ_20180422.tif
#   [====                                                        ]   7%  2.8MB/s    [========                                                    ]  13%  4.5MB/s    [============                                                ]  20%  5.7MB/s    [================                                            ]  27%  6.5MB/s    [====================                                        ]  33%  7.3MB/s    [========================                                    ]  40%  8.0MB/s    [============================                                ]  47%  8.7MB/s    [================================                            ]  53%  9.2MB/s    [====================================                        ]  60%  9.7MB/s   [========================================                    ]  67%  10.0MB/s   [============================================                ]  73%  10.5MB/s   [================================================            ]  80%  10.9MB/s   [====================================================        ]  87%  11.3MB/s   [========================================================    ]  93%  11.6MB/s   [============================================================] 100%  12.2MB/s
# 088/188: SWE_Data\ASO_50M_SWE_USCASJ_20180422.tif.xml
#   [============================================================] 100%
# 089/188: SWE_Data\ASO_50M_SWE_USCACE_20180423.tif
#   [==========                                                  ]  17%  2.8MB/s    [====================                                        ]  33%  4.4MB/s    [==============================                              ]  50%  5.7MB/s    [========================================                    ]  67%  4.6MB/s    [==================================================          ]  83%  5.4MB/s    [============================================================] 100%  5.7MB/s
# 090/188: SWE_Data\ASO_50M_SWE_USCACE_20180423.tif.xml
#   [============================================================] 100%
# 091/188: SWE_Data\ASO_50M_SWE_USCAJW_20180423.tif
#   [====                                                        ]   7%  2.7MB/s    [========                                                    ]  13%  4.2MB/s    [============                                                ]  20%  5.2MB/s    [================                                            ]  27%  6.0MB/s    [====================                                        ]  33%  6.7MB/s    [========================                                    ]  40%  7.1MB/s    [============================                                ]  47%  7.5MB/s    [================================                            ]  53%  7.7MB/s    [====================================                        ]  60%  6.9MB/s    [========================================                    ]  67%  6.5MB/s    [============================================                ]  73%  6.4MB/s    [================================================            ]  80%  6.1MB/s    [====================================================        ]  87%  6.0MB/s    [========================================================    ]  93%  5.8MB/s    [============================================================] 100%  5.8MB/s
# 092/188: SWE_Data\ASO_50M_SWE_USCAJW_20180423.tif.xml
#   [============================================================] 100%
# 093/188: SWE_Data\ASO_50M_SWE_USCASF_20180423.tif
#   [====                                                        ]   7%  2.1MB/s    [========                                                    ]  13%  3.6MB/s    [============                                                ]  20%  4.7MB/s    [================                                            ]  27%  5.8MB/s    [====================                                        ]  33%  5.4MB/s    [========================                                    ]  40%  6.1MB/s    [============================                                ]  47%  6.3MB/s    [================================                            ]  53%  6.6MB/s    [====================================                        ]  60%  6.8MB/s    [========================================                    ]  67%  7.1MB/s    [============================================                ]  73%  7.3MB/s    [================================================            ]  80%  7.5MB/s    [====================================================        ]  87%  7.7MB/s    [========================================================    ]  93%  7.9MB/s    [============================================================] 100%  8.2MB/s
# 094/188: SWE_Data\ASO_50M_SWE_USCASF_20180423.tif.xml
#   [============================================================] 100%
# 095/188: SWE_Data\ASO_50M_SWE_USCATB_20180423.tif
#   [==========                                                  ]  17%  453.2kB/s    [====================                                        ]  33%  567.4kB/s    [==============================                              ]  50%  667.3kB/s    [========================================                    ]  67%  701.0kB/s    [==================================================          ]  83%  750.4kB/s    [============================================================] 100%  843.1kB/s
# 096/188: SWE_Data\ASO_50M_SWE_USCATB_20180423.tif.xml
#   [============================================================] 100%
# 097/188: SWE_Data\ASO_50M_SWE_USCAMB_20180425.tif
#   [====================                                        ]  33%  2.6MB/s    [========================================                    ]  67%  4.0MB/s    [============================================================] 100%  5.6MB/s
# 098/188: SWE_Data\ASO_50M_SWE_USCAMB_20180425.tif.xml
#   [============================================================] 100%
# 099/188: SWE_Data\ASO_50M_SWE_USCAKC_20180426.tif
#   [=======                                                     ]  11%  2.3MB/s    [=============                                               ]  22%  3.9MB/s    [====================                                        ]  33%  4.7MB/s    [===========================                                 ]  44%  5.0MB/s    [=================================                           ]  56%  5.7MB/s    [========================================                    ]  67%  6.1MB/s    [===============================================             ]  78%  6.2MB/s    [=====================================================       ]  89%  6.2MB/s    [============================================================] 100%  6.9MB/s
# 100/188: SWE_Data\ASO_50M_SWE_USCAKC_20180426.tif.xml
#   [============================================================] 100%
# 101/188: SWE_Data\ASO_50M_SWE_USCAKN_20180426.tif
#   [=======                                                     ]  11%  2.9MB/s    [=============                                               ]  22%  4.8MB/s    [====================                                        ]  33%  6.0MB/s    [===========================                                 ]  44%  7.0MB/s    [=================================                           ]  56%  7.8MB/s    [========================================                    ]  67%  8.4MB/s    [===============================================             ]  78%  8.9MB/s    [=====================================================       ]  89%  9.6MB/s   [============================================================] 100%  10.2MB/s
# 102/188: SWE_Data\ASO_50M_SWE_USCAKN_20180426.tif.xml
#   [============================================================] 100%  4.6MB/s
# 103/188: SWE_Data\ASO_50M_SWE_USCACE_20180528.tif
#   [==========                                                  ]  17%  2.6MB/s    [====================                                        ]  33%  4.2MB/s    [==============================                              ]  50%  5.4MB/s    [========================================                    ]  67%  5.8MB/s    [==================================================          ]  83%  6.4MB/s    [============================================================] 100%  7.3MB/s
# 104/188: SWE_Data\ASO_50M_SWE_USCACE_20180528.tif.xml
#   [============================================================] 100%
# 105/188: SWE_Data\ASO_50M_SWE_USCATB_20180528.tif
#   [==========                                                  ]  17%  2.5MB/s    [====================                                        ]  33%  2.7MB/s    [==============================                              ]  50%  3.5MB/s    [========================================                    ]  67%  4.0MB/s    [==================================================          ]  83%  4.4MB/s    [============================================================] 100%  4.9MB/s
# 106/188: SWE_Data\ASO_50M_SWE_USCATB_20180528.tif.xml
#   [============================================================] 100%  209.0kB/s
# 107/188: SWE_Data\ASO_50M_SWE_USCALB_20180601.tif
#   [============================================================] 100%  852.3kB/s
# 108/188: SWE_Data\ASO_50M_SWE_USCALB_20180601.tif.xml
#   [============================================================] 100%
# 109/188: SWE_Data\ASO_50M_SWE_USCASF_20180601.tif
#   [====                                                        ]   7%  2.7MB/s    [========                                                    ]  13%  4.3MB/s    [============                                                ]  20%  5.5MB/s    [================                                            ]  27%  6.5MB/s    [====================                                        ]  33%  7.3MB/s    [========================                                    ]  40%  7.9MB/s    [============================                                ]  47%  8.5MB/s    [================================                            ]  53%  7.4MB/s    [====================================                        ]  60%  8.0MB/s    [========================================                    ]  67%  8.2MB/s    [============================================                ]  73%  8.5MB/s    [================================================            ]  80%  8.6MB/s    [====================================================        ]  87%  8.8MB/s    [========================================================    ]  93%  9.0MB/s    [============================================================] 100%  9.2MB/s
# 110/188: SWE_Data\ASO_50M_SWE_USCASF_20180601.tif.xml
#   [============================================================] 100%
# 111/188: SWE_Data\ASO_50M_SWE_USCASJ_20180601.tif
#   [====                                                        ]   7%  2.5MB/s    [========                                                    ]  13%  3.8MB/s    [============                                                ]  20%  4.9MB/s    [================                                            ]  27%  5.8MB/s    [====================                                        ]  33%  6.4MB/s    [========================                                    ]  40%  6.3MB/s    [============================                                ]  47%  6.3MB/s    [================================                            ]  53%  6.4MB/s    [====================================                        ]  60%  6.5MB/s    [========================================                    ]  67%  6.6MB/s    [============================================                ]  73%  6.8MB/s    [================================================            ]  80%  7.0MB/s    [====================================================        ]  87%  7.1MB/s    [========================================================    ]  93%  7.1MB/s    [============================================================] 100%  7.2MB/s
# 112/188: SWE_Data\ASO_50M_SWE_USCASJ_20180601.tif.xml
#   [============================================================] 100%
# 113/188: SWE_Data\ASO_50M_SWE_USCAJW_20180602.tif
#   [====                                                        ]   7%  2.7MB/s    [========                                                    ]  13%  4.3MB/s    [============                                                ]  20%  5.5MB/s    [================                                            ]  27%  6.6MB/s    [====================                                        ]  33%  7.3MB/s    [========================                                    ]  40%  8.0MB/s    [============================                                ]  47%  8.7MB/s    [================================                            ]  53%  9.3MB/s    [====================================                        ]  60%  9.7MB/s   [========================================                    ]  67%  10.3MB/s   [============================================                ]  73%  10.8MB/s    [================================================            ]  80%  9.5MB/s   [====================================================        ]  87%  10.3MB/s   [========================================================    ]  93%  10.5MB/s   [============================================================] 100%  10.6MB/s
# 114/188: SWE_Data\ASO_50M_SWE_USCAJW_20180602.tif.xml
#   [============================================================] 100%
# 115/188: SWE_Data\ASO_50M_SWE_USCALB_20190309.tif
#   [============================================================] 100%  970.5kB/s
# 116/188: SWE_Data\ASO_50M_SWE_USCALB_20190309.tif.xml
#   [============================================================] 100%
# 117/188: SWE_Data\ASO_50M_SWE_USCAJW_20190315.tif
#   [====                                                        ]   7%  2.3MB/s    [========                                                    ]  13%  3.3MB/s    [============                                                ]  20%  4.1MB/s    [================                                            ]  27%  4.3MB/s    [====================                                        ]  33%  4.6MB/s    [========================                                    ]  40%  4.9MB/s    [============================                                ]  47%  5.0MB/s    [================================                            ]  53%  5.1MB/s    [====================================                        ]  60%  5.3MB/s    [========================================                    ]  67%  5.4MB/s    [============================================                ]  73%  5.5MB/s    [================================================            ]  80%  5.6MB/s    [====================================================        ]  87%  5.7MB/s    [========================================================    ]  93%  5.7MB/s    [============================================================] 100%  5.8MB/s
# 118/188: SWE_Data\ASO_50M_SWE_USCAJW_20190315.tif.xml
#   [============================================================] 100%
# 119/188: SWE_Data\ASO_50M_SWE_USCAKC_20190316.tif
#   [=======                                                     ]  11%  2.5MB/s    [=============                                               ]  22%  4.1MB/s    [====================                                        ]  33%  5.3MB/s    [===========================                                 ]  44%  6.0MB/s    [=================================                           ]  56%  6.8MB/s    [========================================                    ]  67%  6.2MB/s    [===============================================             ]  78%  7.1MB/s    [=====================================================       ]  89%  7.0MB/s    [============================================================] 100%  7.6MB/s
# 120/188: SWE_Data\ASO_50M_SWE_USCAKC_20190316.tif.xml
#   [============================================================] 100%
# 121/188: SWE_Data\ASO_50M_SWE_USCAKW_20190317.tif
#   [========                                                    ]  12%  2.5MB/s    [===============                                             ]  25%  3.9MB/s    [======================                                      ]  38%  4.9MB/s    [==============================                              ]  50%  5.9MB/s    [======================================                      ]  62%  6.7MB/s    [=============================================               ]  75%  7.3MB/s    [====================================================        ]  88%  7.9MB/s    [============================================================] 100%  8.0MB/s
# ...
# 152/188: SWE_Data\ASO_50M_SWE_USCASF_20190502.tif.xml
#   [============================================================] 100%
# 153/188: SWE_Data\ASO_50M_SWE_USCATE_20190503.tif
#   [==========                                                  ]  17%  2.9MB/s    [====================                                        ]  33%  4.5MB/s    [==============================                              ]  50%  5.8MB/s    [========================================                    ]  67%  6.8MB/s    [==================================================          ]  83%  7.6MB/s    [============================================================] 100%  8.6MB/s
# 154/188: SWE_Data\ASO_50M_SWE_USCATE_20190503.tif.xml
#   [============================================================] 100%
# 155/188: SWE_Data\ASO_50M_SWE_USCAMB_20190604.tif
#   [====================                                        ]  33%  422.1kB/s    [========================================                    ]  67%  552.6kB/s    [============================================================] 100%  790.7kB/s
# 156/188: SWE_Data\ASO_50M_SWE_USCAMB_20190604.tif.xml
#   [============================================================] 100%
# 157/188: SWE_Data\ASO_50M_SWE_USCAJW_20190605.tif
#   [====                                                        ]   7%  2.8MB/s    [========                                                    ]  13%  4.5MB/s    [============                                                ]  20%  5.7MB/s    [================                                            ]  27%  6.6MB/s    [====================                                        ]  33%  6.1MB/s    [========================                                    ]  40%  6.4MB/s    [============================                                ]  47%  6.7MB/s    [================================                            ]  53%  7.0MB/s    [====================================                        ]  60%  7.3MB/s    [========================================                    ]  67%  7.5MB/s    [============================================                ]  73%  7.7MB/s    [================================================            ]  80%  8.0MB/s    [====================================================        ]  87%  8.2MB/s    [========================================================    ]  93%  8.4MB/s    [============================================================] 100%  8.7MB/s
# 158/188: SWE_Data\ASO_50M_SWE_USCAJW_20190605.tif.xml
#   [============================================================] 100%
# 159/188: SWE_Data\ASO_50M_SWE_USCAKC_20190608.tif
#   [=======                                                     ]  11%  2.8MB/s    [=============                                               ]  22%  4.6MB/s    [====================                                        ]  33%  6.0MB/s    [===========================                                 ]  44%  5.7MB/s    [=================================                           ]  56%  5.6MB/s    [========================================                    ]  67%  5.8MB/s    [===============================================             ]  78%  6.0MB/s    [=====================================================       ]  89%  6.1MB/s    [============================================================] 100%  6.6MB/s
# 160/188: SWE_Data\ASO_50M_SWE_USCAKC_20190608.tif.xml
#   [============================================================] 100%
# 161/188: SWE_Data\ASO_50M_SWE_USCASF_20190609.tif
#   [====                                                        ]   7%  1.2MB/s    [========                                                    ]  13%  1.5MB/s    [============                                                ]  20%  1.8MB/s    [================                                            ]  27%  2.0MB/s    [====================                                        ]  33%  2.2MB/s    [========================                                    ]  40%  2.3MB/s    [============================                                ]  47%  2.4MB/s    [================================                            ]  53%  2.4MB/s    [====================================                        ]  60%  2.5MB/s    [========================================                    ]  67%  2.6MB/s    [============================================                ]  73%  2.7MB/s    [================================================            ]  80%  2.7MB/s    [====================================================        ]  87%  2.8MB/s    [========================================================    ]  93%  2.8MB/s    [============================================================] 100%  2.9MB/s
# 162/188: SWE_Data\ASO_50M_SWE_USCASF_20190609.tif.xml
#   [============================================================] 100%
# 163/188: SWE_Data\ASO_50M_SWE_USCAKC_20190611.tif
#   [=======                                                     ]  11%  2.8MB/s    [=============                                               ]  22%  4.5MB/s    [====================                                        ]  33%  5.8MB/s    [===========================                                 ]  44%  6.7MB/s    [=================================                           ]  56%  7.5MB/s    [========================================                    ]  67%  7.0MB/s    [===============================================             ]  78%  7.5MB/s    [=====================================================       ]  89%  7.8MB/s    [============================================================] 100%  8.4MB/s
# 164/188: SWE_Data\ASO_50M_SWE_USCAKC_20190611.tif.xml
#   [============================================================] 100%
# 165/188: SWE_Data\ASO_50M_SWE_USCALB_20190611.tif
#   [============================================================] 100%  1.1MB/s
# 166/188: SWE_Data\ASO_50M_SWE_USCALB_20190611.tif.xml
#   [============================================================] 100%
# 167/188: SWE_Data\ASO_50M_SWE_USCATE_20190613.tif
#   [==========                                                  ]  17%  2.9MB/s    [====================                                        ]  33%  3.4MB/s    [==============================                              ]  50%  4.4MB/s    [========================================                    ]  67%  4.6MB/s    [==================================================          ]  83%  4.7MB/s    [============================================================] 100%  5.3MB/s
# 168/188: SWE_Data\ASO_50M_SWE_USCATE_20190613.tif.xml
#   [============================================================] 100%  210.1kB/s
# 169/188: SWE_Data\ASO_50M_SWE_USCASJ_20190614.tif
#   [====                                                        ]   7%  2.8MB/s    [========                                                    ]  13%  4.5MB/s    [============                                                ]  20%  5.8MB/s    [================                                            ]  27%  6.7MB/s    [====================                                        ]  33%  7.6MB/s    [========================                                    ]  40%  8.3MB/s    [============================                                ]  47%  7.3MB/s    [================================                            ]  53%  7.7MB/s    [====================================                        ]  60%  8.0MB/s    [========================================                    ]  67%  7.4MB/s    [============================================                ]  73%  7.5MB/s    [================================================            ]  80%  7.6MB/s    [====================================================        ]  87%  7.7MB/s    [========================================================    ]  93%  7.9MB/s    [============================================================] 100%  8.1MB/s
# 170/188: SWE_Data\ASO_50M_SWE_USCASJ_20190614.tif.xml
#   [============================================================] 100%
# 171/188: SWE_Data\ASO_50M_SWE_USCALB_20190703.tif
#   [============================================================] 100%  1.0MB/s
# 172/188: SWE_Data\ASO_50M_SWE_USCALB_20190703.tif.xml
#   [============================================================] 100%
# 173/188: SWE_Data\ASO_50M_SWE_USCAMB_20190703.tif
#   [====================                                        ]  33%  2.8MB/s    [========================================                    ]  67%  4.5MB/s    [============================================================] 100%  6.2MB/s
# 174/188: SWE_Data\ASO_50M_SWE_USCAMB_20190703.tif.xml
#   [============================================================] 100%
# 175/188: SWE_Data\ASO_50M_SWE_USCASF_20190704.tif
#   [====                                                        ]   7%  459.8kB/s    [========                                                    ]  13%  601.2kB/s    [============                                                ]  20%  693.4kB/s    [================                                            ]  27%  784.1kB/s    [====================                                        ]  33%  869.3kB/s    [========================                                    ]  40%  938.4kB/s    [============================                                ]  47%  999.0kB/s    [================================                            ]  53%  1.1MB/s    [====================================                        ]  60%  1.1MB/s    [========================================                    ]  67%  1.2MB/s    [============================================                ]  73%  1.2MB/s    [================================================            ]  80%  1.2MB/s    [====================================================        ]  87%  1.3MB/s    [========================================================    ]  93%  1.3MB/s    [============================================================] 100%  1.4MB/s
# 176/188: SWE_Data\ASO_50M_SWE_USCASF_20190704.tif.xml
#   [============================================================] 100%
# 177/188: SWE_Data\ASO_50M_SWE_USCASJ_20190704.tif
#   [====                                                        ]   7%  2.9MB/s    [========                                                    ]  13%  4.7MB/s    [============                                                ]  20%  5.9MB/s    [================                                            ]  27%  6.9MB/s    [====================                                        ]  33%  7.7MB/s    [========================                                    ]  40%  8.3MB/s    [============================                                ]  47%  6.7MB/s    [================================                            ]  53%  6.7MB/s    [====================================                        ]  60%  6.8MB/s    [========================================                    ]  67%  6.9MB/s    [============================================                ]  73%  7.0MB/s    [================================================            ]  80%  7.2MB/s    [====================================================        ]  87%  7.3MB/s    [========================================================    ]  93%  7.4MB/s    [============================================================] 100%  7.6MB/s
# 178/188: SWE_Data\ASO_50M_SWE_USCASJ_20190704.tif.xml
#   [============================================================] 100%
# 179/188: SWE_Data\ASO_50M_SWE_USCATE_20190705.tif
#   [==========                                                  ]  17%  2.1MB/s    [====================                                        ]  33%  3.5MB/s    [==============================                              ]  50%  4.5MB/s    [========================================                    ]  67%  5.3MB/s    [==================================================          ]  83%  5.8MB/s    [============================================================] 100%  6.7MB/s
# 180/188: SWE_Data\ASO_50M_SWE_USCATE_20190705.tif.xml
#   [============================================================] 100%  5.5MB/s
# 181/188: SWE_Data\ASO_50M_SWE_USCASJ_20190713.tif
#   [====                                                        ]   7%  1.9MB/s    [========                                                    ]  13%  3.0MB/s    [============                                                ]  20%  3.8MB/s    [================                                            ]  27%  4.4MB/s    [====================                                        ]  33%  4.7MB/s    [========================                                    ]  40%  5.0MB/s    [============================                                ]  47%  5.3MB/s    [================================                            ]  53%  5.7MB/s    [====================================                        ]  60%  5.9MB/s    [========================================                    ]  67%  5.4MB/s    [============================================                ]  73%  5.4MB/s    [================================================            ]  80%  5.4MB/s    [====================================================        ]  87%  5.5MB/s    [========================================================    ]  93%  5.5MB/s    [============================================================] 100%  5.7MB/s
# 182/188: SWE_Data\ASO_50M_SWE_USCASJ_20190713.tif.xml
#   [============================================================] 100%
# 183/188: SWE_Data\ASO_50M_SWE_USCASF_20190714.tif
#   [====                                                        ]   7%  2.7MB/s    [========                                                    ]  13%  4.5MB/s    [============                                                ]  20%  5.7MB/s    [================                                            ]  27%  6.7MB/s    [====================                                        ]  33%  7.5MB/s    [========================                                    ]  40%  8.4MB/s    [============================                                ]  47%  7.4MB/s    [================================                            ]  53%  8.0MB/s    [====================================                        ]  60%  8.3MB/s    [========================================                    ]  67%  8.5MB/s    [============================================                ]  73%  8.5MB/s    [================================================            ]  80%  8.8MB/s    [====================================================        ]  87%  8.9MB/s    [========================================================    ]  93%  9.1MB/s    [============================================================] 100%  9.3MB/s
# 184/188: SWE_Data\ASO_50M_SWE_USCASF_20190714.tif.xml
#   [============================================================] 100%
# 185/188: SWE_Data\ASO_50M_SWE_USCALB_20190715.tif
#   [============================================================] 100%  1.1MB/s
# 186/188: SWE_Data\ASO_50M_SWE_USCALB_20190715.tif.xml
#   [============================================================] 100%
# 187/188: SWE_Data\ASO_50M_SWE_USCAMB_20190716.tif
#   [====================                                        ]  33%  2.8MB/s    [========================================                    ]  67%  4.6MB/s    [============================================================] 100%  6.6MB/s
# 188/188: SWE_Data\ASO_50M_SWE_USCAMB_20190716.tif.xml
#   [============================================================] 100%  1.3MB/s
# Files with .xml extension moved to the destination folder.

# %%
class ASODataProcessing:
    @staticmethod
    def processing_tiff(input_file, output_res):
        try:
            # Extract date from the input file name
            date = os.path.splitext(input_file)[0].split("_")[-1]
            
            # Define the output file path
            output_folder = os.path.join(os.getcwd(), "Processed_data")
            os.makedirs(output_folder, exist_ok=True)
            output_file = os.path.join(output_folder, f"ASO_100M_{date}.tif")
    
            # Open the input TIFF file
            ds = gdal.Open(input_file)
    
            if ds is None:
                print(f"Failed to open '{input_file}'. Make sure the file is a valid GeoTIFF file.")
                return None
            
            # Reproject and resample
            gdal.Warp(output_file, ds, dstSRS="EPSG:4326", xRes=output_res, yRes=-output_res, resampleAlg="bilinear")
    
            # Read the processed TIFF file using rasterio
            rds = rxr.open_rasterio(output_file)
            rds = rds.squeeze().drop("spatial_ref").drop("band")
            rds.name = "data"
            df = rds.to_dataframe().reset_index()
            return df
    
        except Exception as e:
            print(f"An error occurred: {str(e)}")
            return None
        
    @staticmethod
    def convert_tiff_to_csv(input_folder, cwd, output_res):
        # Check if the folder exists
        folder_path = os.path.join(cwd, input_folder)
        if not os.path.exists(folder_path) or not os.path.isdir(folder_path):
            print(f"The folder '{input_folder}' does not exist.")
            return
        # Check if the folder is empty
        if not os.listdir(folder_path):
            print(f"The folder '{input_folder}' is empty.")
            return
    
        # Get a list of TIFF files in the folder
        tiff_files = [filename for filename in os.listdir(folder_path) if filename.endswith(".tif")]
    
        # Create CSV files from TIFF files
        for tiff_filename in tiff_files:
            # Open the TIFF file
            tiff_filepath = os.path.join(folder_path, tiff_filename)
            df = processing_tiff(tiff_filepath, output_res)
    
            if df is not None:
                # Get the date from the TIFF filename
                date = os.path.splitext(tiff_filename)[0].split("_")[-1]
    
                # Define the CSV filename and folder
                csv_filename = f"ASO_SWE_{date}.csv"
                csv_folder = os.path.join(cwd, "Processed_Data", "SWE_csv")
                os.makedirs(csv_folder, exist_ok=True)
                csv_filepath = os.path.join(csv_folder, csv_filename)
    
                # Save the DataFrame as a CSV file
                df.to_csv(csv_filepath, index=False)
    
                print(f"Converted '{tiff_filename}' to '{csv_filename}'")
                
    
    def extract_cellids(self, metadata_path, aso_swe_path, output_path):

        prediction_observation_metadata_df = pd.read_csv(metadata_path)
    
        # Convert the DataFrame into a GeoDataFrame by creating a Polygon geometry
        geometry = [Polygon([(row['BL_Coord_Long'], row['BL_Coord_Lat']),
                             (row['BR_Coord_Long'], row['BR_Coord_Lat']),
                             (row['UR_Coord_Long'], row['UR_Coord_Lat']),
                             (row['UL_Coord_Long'], row['UL_Coord_Lat'])]) 
                    for _, row in prediction_observation_metadata_df.iterrows()]
    
        # Add the geometry to the DataFrame and create a GeoDataFrame
        prediction_observation_metadata = gpd.GeoDataFrame(prediction_observation_metadata_df, geometry=geometry)
    
        # Load ASO SWE DataFrame
        aso_swe_df = pd.read_csv(aso_swe_path)
    
        # Convert the "aso_swe_df" into a GeoDataFrame with point geometries
        geometry = [Point(xy) for xy in zip(aso_swe_df['x'], aso_swe_df['y'])]
        aso_swe_geo = gpd.GeoDataFrame(aso_swe_df, geometry=geometry)
    
        result = gpd.sjoin(aso_swe_geo, prediction_observation_metadata, how='inner', predicate='intersects')
        Final_df = result[['y', 'x', 'data', 'cell_id']]
        
        #Final_df = result.drop(columns_to_drop, axis=1)
    
        # Rename the 'data' column to 'swe'
        Final_df.rename(columns={'data': 'swe'}, inplace=True)
    
        # Save the final DataFrame to the specified output CSV file
        Final_df.to_csv(output_path, index=False)
        
        return
    
    def process_folder(self, input_folder, metadata_path, output_folder):
        
        # List all CSV files in the input folder
        csv_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]

        for csv_file in csv_files:
            # Create the full file paths for input and output
            input_aso_path = os.path.join(input_folder, csv_file)
            output_aso_path = os.path.join(output_folder, csv_file)

            # Check if the output file already exists
            if os.path.exists(output_aso_path):
                print(f"CSV file {csv_file} already exists in the output folder.")
                continue

            # Process the CSV file using the extract_cellids function
            self.extract_cellids(metadata_path, input_aso_path, output_aso_path)
            print(f"Processed {csv_file}")

    def converting_ASO_to_standardized_format(self, input_folder, output_csv):
        # Initialize an empty DataFrame to store the final transformed data
        final_df = pd.DataFrame()
    
        # Iterate through all CSV files in the directory
        for filename in os.listdir(input_folder):
            if filename.endswith(".csv"):
                file_path = os.path.join(input_folder, filename)
    
                # Extract the time frame from the filename
                time_frame = filename.split('_')[-1].split('.')[0]
    
                # Read the CSV file into a DataFrame
                df = pd.read_csv(file_path)
    
                # Rename the 'SWE' column to the time frame for clarity
                df = df.rename(columns={'SWE': time_frame})
    
                # Merge or concatenate the data into the final DataFrame
                if final_df.empty:
                    final_df = df
                else:
                    final_df = pd.merge(final_df, df, on='cell_id', how='outer')
    
        # Save the final transformed DataFrame to a single CSV file
        final_df.to_csv(output_csv, index=False)
        
if __name__ == "__main__":
    
    data_processor = ASODataProcessing()
    folder_name = "SWE_Data"
    cwd = os.getcwd()
    output_res = 0.001
    data_processor.convert_tiff_to_csv(folder_name, cwd, output_res)

    input_folder = r"C:\Users\VISH NU\NSM_EvaluationTool\Standardized-Snow-Water-Equivalent-Evaluation-Tool\SSWEET\Processed_Data\SWE_csv"
    metadata_path = r"C:\Users\VISH NU\NSM_EvaluationTool\Standardized-Snow-Water-Equivalent-Evaluation-Tool\SSWEET\Provided_Data\Prediction_Sierras_Metadata.csv"
    output_folder = r"C:\Users\VISH NU\NSM_EvaluationTool\Standardized-Snow-Water-Equivalent-Evaluation-Tool\SSWEET\Processed_SWE"
    data_processor.process_folder(input_folder, metadata_path, output_folder)

# %%
import geopandas as gpd
from shapely.geometry import Point, Polygon
import pandas as pd
import numpy as np
import os

def load_aso_snotel_geometry(aso_swe_file):
    
    aso_file = pd.read_csv("C:\Users\VISH NU\NSM_EvaluationTool\Standardized-Snow-Water-Equivalent-Evaluation-Tool\SSWEET\Processed_SWE" + aso_swe_file)
    aso_file.set_index('cell_id', inplace=True)
    aso_geometry = [Point(xy) for xy in zip(aso_file['x'], aso_file['y'])]
    aso_gdf = gpd.GeoDataFrame(aso_file, geometry=aso_geometry)

    return aso_gdf

def calculate_nearest_snotel(aso_gdf, snotel_gdf, n=6, distance_cache=None):

    if distance_cache is None:
        distance_cache = {}

    nearest_snotel = {}
    for idx, aso_row in aso_gdf.iterrows():
        cell_id = idx

        # Check if distances for this cell_id are already calculated and cached
        if cell_id in distance_cache:
            nearest_snotel[idx] = distance_cache[cell_id]
        else:
            # Calculate Haversine distances between the grid cell and all SNOTEL locations
            distances = haversine_vectorized(
                aso_row.geometry.y, aso_row.geometry.x,
                snotel_gdf.geometry.y.values, snotel_gdf.geometry.x.values)

            # Store the nearest stations in the cache
            nearest_snotel[idx] = list(snotel_gdf['station_id'].iloc[distances.argsort()[:n]])
            distance_cache[cell_id] = nearest_snotel[idx]

    return nearest_snotel, distance_cache

def haversine_vectorized(lat1, lon1, lat2, lon2):
    
    lon1 = np.radians(lon1)
    lon2 = np.radians(lon2)
    lat1 = np.radians(lat1)
    lat2 = np.radians(lat2)

    # Haversine formula
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    
    r = 6371.0
    # Distance calculation
    distances = r * c

    return distances

def fetch_snotel_sites_for_cellids(aso_swe_files_folder_path):
    final_df = pd.DataFrame()

    snotel_data = pd.read_csv(r"C:\Users\VISH NU\National_snow_model\National-Snow-Model\Data\Provided_Data\ground_measures_train_features.csv")
    date_columns = snotel_data.columns[1:]
    new_column_names = {col: pd.to_datetime(col, format='%m/%d/%Y').strftime('%Y%m%d') for col in date_columns}
    snotel_data_f = snotel_data.rename(columns=new_column_names)
    
    aso_swe_files = os.listdir(aso_swe_files_folder_path)
    
    for aso_swe_file in aso_swe_files:
        
        if os.path.isdir(os.path.join(aso_swe_files_folder_path, aso_swe_file)):
            continue
        
        # Extract the timestamp from the ASO SWE file name
        timestamp = aso_swe_file.split('_')[-1].split('.')[0]
        print(f"Processing file with timestamp: {timestamp}")

        # Load ASO SWE data
        aso_gdf = load_aso_snotel_geometry(aso_swe_file)
        aso_swe_data = pd.read_csv(r"C:\Users\VISH NU\NSM_EvaluationTool\Standardized-Snow-Water-Equivalent-Evaluation-Tool\SSWEET\Processed_SWE" + aso_swe_file)
        
        snotel_file = pd.read_csv(r"C:\Users\VISH NU\NSM_EvaluationTool\Standardized-Snow-Water-Equivalent-Evaluation-Tool\SSWEET\Provided_Data\ground_measures_metadata.csv")
        snotel_geometry = [Point(xy) for xy in zip(snotel_file['longitude'], snotel_file['latitude'])]
        snotel_gdf = gpd.GeoDataFrame(snotel_file, geometry=snotel_geometry)
        
        nearest_snotel, distance_cache = calculate_nearest_snotel(aso_gdf, snotel_gdf, n=6)
        print(f"calculated nearest snotel for file with timestamp {timestamp}")
        #print(nearest_snotel)
        
        transposed_data = {}

        if timestamp in new_column_names.values():
            
            for idx, aso_row in aso_gdf.iterrows():
                cell_id = idx
                station_ids = nearest_snotel[cell_id]

                selected_snotel_data = snotel_data_f[['station_id', timestamp]].loc[snotel_data_f['station_id'].isin(station_ids)]
                station_mapping = {old_id: f"Site {i+1}" for i, old_id in enumerate(station_ids)}
    
                # Rename the station IDs in the selected SNOTEL data
                selected_snotel_data['station_id'] = selected_snotel_data['station_id'].map(station_mapping)
        
                # Transpose and set the index correctly
                transposed_data[cell_id] = selected_snotel_data.set_index('station_id').T

            # Concatenate the transposed data along the rows
            transposed_df = pd.concat(transposed_data, axis=0)
    
            # Reset index and rename columns
            transposed_df = transposed_df.reset_index()
            transposed_df.rename(columns={'level_0': 'cell_id', 'level_1': 'Date'}, inplace=True)
            transposed_df['Date'] = pd.to_datetime(transposed_df['Date'])

            #aso_swe_data = pd.read_csv('Processed_SWE/' + aso_swe_file)
            aso_swe_data['Date'] = pd.to_datetime(timestamp)
            aso_swe_data = aso_swe_data[['cell_id', 'Date', 'swe']]

            # Merge on 'cell_id' and 'Date'
            merged_df = pd.merge(aso_swe_data, transposed_df, how='left', on=['cell_id', 'Date'])

            final_df = pd.concat([final_df, merged_df], ignore_index=True)
            
        else:
            aso_swe_data['Date'] = pd.to_datetime(timestamp)
            aso_swe_data = aso_swe_data[['cell_id', 'Date', 'swe']]
    
            # No need to merge in this case, directly concatenate
            final_df = pd.concat([final_df, aso_swe_data], ignore_index=True)

    # Save the merged data to a new file
    output_filename = "C:\Users\VISH NU\NSM_EvaluationTool\Standardized-Snow-Water-Equivalent-Evaluation-Tool\SSWEET\Merged_aso_snotel_swe_data.csv"
    final_df.to_csv(output_filename, index=False)
    print("Processed and saved data.")
    
if __name__ == "__main__":
    aso_swe_files_folder_path = r"C:\Users\VISH NU\NSM_EvaluationTool\Standardized-Snow-Water-Equivalent-Evaluation-Tool\SSWEET\Processed_SWE"
    
    fetch_snotel_sites_for_cellids(aso_swe_files_folder_path)

# %%
transposed_df
# Out:
# station_id                               cell_id       Date  CDEC:DDM  \
# 0           84957e84-2d2a-4dca-9e88-e1a93553b91b 2016-06-07       7.2
# 1           3f5428a0-5a53-4075-8568-97f8d19b1ba0 2016-06-07       7.2
# 2           555c1c33-77a4-4aa3-8f71-5d0c9d1bdb98 2016-06-07       NaN
# 3           76eb116c-ae69-4716-b975-13f6151f1de1 2016-06-07       7.2
# 4           0a3c7304-1506-4aa8-be55-df7a1678433d 2016-06-07       7.2
# ..                                           ...        ...       ...
# 521         32c81fd8-4b67-43b5-8c9f-95166494ec3b 2016-06-07       NaN
# 522         53d89680-b908-428e-965b-882d881e058a 2016-06-07       NaN
# 523         0bd2b156-8c6c-4b11-bf50-075891a572b9 2016-06-07       NaN
# 524         bba1bf1b-94dd-4b3e-bbce-65a0e6d12a48 2016-06-07       NaN
# 525         a922756d-9e3e-4456-991a-4346343c5ca2 2016-06-07       NaN
#
# station_id  CDEC:GNL  CDEC:HRS  CDEC:LVT  CDEC:PDS  SNOTEL:771_CA_SNTL  \
# 0                7.8      5.07      35.5       NaN                 0.0
# 1                7.8      5.07      35.5       NaN                 0.0
# 2                NaN      5.07      35.5       NaN                 0.0
# 3                7.8      5.07      35.5       NaN                 0.0
# 4                7.8      5.07      35.5       NaN                 0.0
# ..               ...       ...       ...       ...                 ...
# 521              NaN       NaN       NaN       NaN                 NaN
# 522              NaN       NaN       NaN       NaN                 NaN
# 523              NaN       NaN       NaN       NaN                 NaN
# 524              NaN       NaN       NaN       NaN                 NaN
# 525              NaN       NaN       NaN       NaN                 NaN
#
# station_id  CDEC:LVM  CDEC:SPS  ...  CDEC:DAN  CDEC:WHW  CDEC:TUM  CDEC:TNY  \
# 0                NaN       NaN  ...       NaN       NaN       NaN       NaN
# 1                NaN       NaN  ...       NaN       NaN       NaN       NaN
# 2                0.0       0.0  ...       NaN       NaN       NaN       NaN
# 3                NaN       NaN  ...       NaN       NaN       NaN       NaN
# 4                NaN       NaN  ...       NaN       NaN       NaN       NaN
# ..               ...       ...  ...       ...       ...       ...       ...
# 521              NaN       NaN  ...       0.4       NaN       NaN       NaN
# 522              NaN       NaN  ...       0.4       NaN       NaN       NaN
# 523              NaN       NaN  ...       0.4       NaN       NaN       NaN
# 524              NaN       NaN  ...       0.4       NaN       NaN       NaN
# 525              NaN       NaN  ...       0.4       NaN       NaN       NaN
#
# station_id  CDEC:GIN  CDEC:GEM  CDEC:AGP  CDEC:DPO  CDEC:GRM  CDEC:CHM
# 0                NaN       NaN       NaN       NaN       NaN       NaN
# 1                NaN       NaN       NaN       NaN       NaN       NaN
# 2                NaN       NaN       NaN       NaN       NaN       NaN
# 3                NaN       NaN       NaN       NaN       NaN       NaN
# 4                NaN       NaN       NaN       NaN       NaN       NaN
# ..               ...       ...       ...       ...       ...       ...
# 521              NaN      1.12       NaN       NaN       NaN       NaN
# 522              NaN      1.12       NaN       NaN       NaN       NaN
# 523              NaN      1.12       NaN       NaN       NaN       NaN
# 524              NaN      1.12       0.0       NaN       NaN       NaN
# 525              NaN      1.12       0.0       NaN      0.36       NaN
#
# [526 rows x 22 columns]

# %%
nearest_snotel
# Out:
# {'9df80f3c-92d8-446d-83a6-b122552c1513': ['CDEC:GNL',
#   'CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:PDS',
#   'CDEC:DDM',
#   'SNOTEL:771_CA_SNTL'],
#  '452fd93c-d72b-446a-9e80-dfe8567144b4': ['CDEC:GNL',
#   'CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:PDS',
#   'CDEC:DDM',
#   'SNOTEL:771_CA_SNTL'],
#  'e3dca911-f2b3-434c-a672-d5e19cca1cf3': ['CDEC:HRS',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL',
#   'CDEC:DDM',
#   'CDEC:GNL',
#   'CDEC:PDS'],
#  '84957e84-2d2a-4dca-9e88-e1a93553b91b': ['CDEC:GNL',
#   'CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:PDS',
#   'CDEC:DDM',
#   'SNOTEL:771_CA_SNTL'],
#  '3f5428a0-5a53-4075-8568-97f8d19b1ba0': ['CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'CDEC:PDS',
#   'CDEC:DDM',
#   'SNOTEL:771_CA_SNTL'],
#  'f59b542e-80ca-4718-8062-576a66ce7010': ['CDEC:HRS',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL',
#   'CDEC:PDS',
#   'CDEC:SPS',
#   'CDEC:DDM'],
#  '555c1c33-77a4-4aa3-8f71-5d0c9d1bdb98': ['CDEC:HRS',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM',
#   'CDEC:SPS'],
#  '3d8f5ca5-53d4-4e3a-8746-752b0d8d0278': ['CDEC:HRS',
#   'CDEC:LVT',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM',
#   'SNOTEL:771_CA_SNTL',
#   'CDEC:SPS'],
#  '76eb116c-ae69-4716-b975-13f6151f1de1': ['CDEC:GNL',
#   'CDEC:HRS',
#   'CDEC:PDS',
#   'CDEC:LVT',
#   'CDEC:DDM',
#   'SNOTEL:771_CA_SNTL'],
#  '0a3c7304-1506-4aa8-be55-df7a1678433d': ['CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:PDS',
#   'CDEC:LVT',
#   'CDEC:DDM',
#   'SNOTEL:771_CA_SNTL'],
#  '347ae172-aa73-4907-93e8-1a4a7f4dde86': ['CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'CDEC:PDS',
#   'CDEC:DDM',
#   'SNOTEL:771_CA_SNTL'],
#  '0c42cd29-c9ab-4a00-8961-9079565fe1d3': ['CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:PDS',
#   'SNOTEL:771_CA_SNTL',
#   'CDEC:GNL',
#   'CDEC:DDM'],
#  'efe49d51-722f-493d-be52-b2cf327f9069': ['CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:PDS',
#   'SNOTEL:771_CA_SNTL',
#   'CDEC:SPS',
#   'CDEC:DDM'],
#  'c484e710-c5ca-4ce6-8e41-42d38a3291e7': ['CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:PDS',
#   'SNOTEL:771_CA_SNTL',
#   'CDEC:SPS',
#   'CDEC:DDM'],
#  'a01bac03-84b5-4033-981e-aa43245cecd7': ['CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:PDS',
#   'SNOTEL:771_CA_SNTL',
#   'CDEC:SPS',
#   'SNOTEL:575_CA_SNTL'],
#  '00de0c26-3fe8-4a93-94b6-681afba74bfd': ['CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:PDS',
#   'SNOTEL:771_CA_SNTL',
#   'CDEC:SPS',
#   'SNOTEL:575_CA_SNTL'],
#  '6958b824-19ac-4212-a2d6-04419e1a402d': ['CDEC:GNL',
#   'CDEC:HRS',
#   'CDEC:PDS',
#   'CDEC:LVT',
#   'CDEC:DDM',
#   'SNOTEL:771_CA_SNTL'],
#  'cdf12516-ad9d-4ab7-b01a-0868fb003cc5': ['CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:PDS',
#   'CDEC:LVT',
#   'CDEC:DDM',
#   'SNOTEL:771_CA_SNTL'],
#  '2b240429-3143-4f1d-8aba-6296575b1fdf': ['CDEC:HRS',
#   'CDEC:PDS',
#   'CDEC:LVT',
#   'CDEC:GNL',
#   'SNOTEL:771_CA_SNTL',
#   'CDEC:DDM'],
#  '33bf61f4-8c90-4a27-b6b9-1d7c4acd0ce6': ['CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:PDS',
#   'SNOTEL:771_CA_SNTL',
#   'CDEC:SPS',
#   'SNOTEL:575_CA_SNTL'],
#  '3407dd59-6d78-49b5-8bfb-51522a12996d': ['CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:PDS',
#   'SNOTEL:771_CA_SNTL',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM'],
#  '4802e52a-40a1-4954-be70-ec7bf42c7e79': ['CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:PDS',
#   'CDEC:LVT',
#   'CDEC:DDM',
#   'SNOTEL:771_CA_SNTL'],
#  '104b6603-296a-4abe-8ad5-399365907669': ['CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:PDS',
#   'CDEC:LVT',
#   'CDEC:DDM',
#   'SNOTEL:771_CA_SNTL'],
#  '72dd5da5-f1c6-4389-9580-9dd483b8ba1b': ['CDEC:HRS',
#   'CDEC:PDS',
#   'CDEC:LVT',
#   'CDEC:GNL',
#   'SNOTEL:771_CA_SNTL',
#   'CDEC:DDM'],
#  'b05db078-51cf-400c-90d1-557169c0f8ff': ['CDEC:HRS',
#   'CDEC:PDS',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL',
#   'CDEC:SPS',
#   'SNOTEL:575_CA_SNTL'],
#  '16d875b5-f979-4a2d-9ef3-721a1a4a505b': ['CDEC:HRS',
#   'CDEC:PDS',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:SPS'],
#  'daf7c840-0f92-4b03-829a-482420631ca0': ['CDEC:HRS',
#   'CDEC:PDS',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM'],
#  'b5b132e4-bd28-4b9f-9f32-b87e10bce204': ['CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:PDS',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM',
#   'SNOTEL:771_CA_SNTL'],
#  '1eb34404-7029-413c-a2c6-172eb67f7d27': ['CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:PDS',
#   'CDEC:LVT',
#   'CDEC:DDM',
#   'SNOTEL:771_CA_SNTL'],
#  'f163804a-7ffb-4b20-b364-a0853844af65': ['CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:PDS',
#   'CDEC:LVT',
#   'CDEC:DDM',
#   'SNOTEL:771_CA_SNTL'],
#  
['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'CDEC:WHW',
#   'CDEC:DDM'],
#  '2de8f6ae-5599-4e17-9d5b-affaab2a57ea': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'CDEC:WHW',
#   'SNOTEL:771_CA_SNTL'],
#  '0932bf25-81d6-43b4-909a-13a5665abc88': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'CDEC:WHW',
#   'SNOTEL:771_CA_SNTL'],
#  '5f2e0dd3-b5c2-49b7-9e88-37d69d8d5581': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'CDEC:WHW',
#   'SNOTEL:771_CA_SNTL'],
#  '508c0095-54f5-4aae-b095-6ce179f8366e': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:GNL',
#   'CDEC:WHW',
#   'SNOTEL:771_CA_SNTL'],
#  '69ae02d1-9848-4dfd-a97d-2fc7dfcfe03f': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:LVT',
#   'SNOTEL:575_CA_SNTL',
#   'SNOTEL:771_CA_SNTL',
#   'CDEC:LVM'],
#  '77936df6-920e-4750-97be-cd980c4eb2a8': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:LVT',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM',
#   'SNOTEL:771_CA_SNTL'],
#  'c64e7cab-b079-41c4-8c9d-e956a271f9a5': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:LVT',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM',
#   'SNOTEL:771_CA_SNTL'],
#  '84484c4e-f20e-42ec-aae9-d987698e1345': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:VRG',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM'],
#  'c819f249-e357-4198-9c6a-46cc86a11999': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:VRG',
#   'CDEC:LVT',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM'],
#  '70a8fbac-6968-46c8-bd00-eed221c1c58f': ['CDEC:VRG',
#   'CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:TUM',
#   'CDEC:DAN',
#   'SNOTEL:575_CA_SNTL'],
#  '8656e23d-35d4-4a2a-970f-965fc512ac4b': ['CDEC:VRG',
#   'CDEC:DAN',
#   'CDEC:TUM',
#   'CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:TNY'],
#  'aadc940b-1a2b-4be5-b889-4cbeb1dbc3b0': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'CDEC:WHW',
#   'CDEC:DDM'],
#  '00c963cd-72d0-4a7a-bc85-879479ab216f': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'CDEC:WHW',
#   'SNOTEL:771_CA_SNTL'],
#  '2cb1db3e-caa9-4680-ac17-675bff60dc6e': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'CDEC:WHW',
#   'SNOTEL:771_CA_SNTL'],
#  'f2a11109-76c1-4e97-920e-fa44bf972079': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'CDEC:WHW',
#   'SNOTEL:771_CA_SNTL'],
#  'eb46a598-624a-40e0-80d5-bed284fdeb7b': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:WHW',
#   'CDEC:GNL',
#   'SNOTEL:771_CA_SNTL'],
#  '9f578e5e-1dbc-48ce-a1b0-9682e3956151': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:WHW',
#   'SNOTEL:575_CA_SNTL',
#   'SNOTEL:771_CA_SNTL'],
#  'd99e8b76-a30c-425b-8397-48d1bb2e4878': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:WHW',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM'],
#  '68ab8ec7-326d-44df-b83a-86807ccbbec2': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:WHW',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM'],
#  '0c37a6b3-f4f0-45e5-b86f-ac3ba6d24dae': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:WHW',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM'],
#  '4f3faf6d-8fbc-43be-85dc-e206804a55d6': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:LVT',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM',
#   'CDEC:VRG'],
#  'bbc275b4-9aa7-4662-a897-1b74e0519187': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:VRG',
#   'CDEC:LVT',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM'],
#  '3eaa3b03-b3de-48ed-9ec8-c46b638f3b38': ['CDEC:PDS',
#   'CDEC:VRG',
#   'CDEC:HRS',
#   'CDEC:TUM',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM'],
#  'db3578aa-dd53-44d2-b4bd-0a3620cdcdaf': ['CDEC:VRG',
#   'CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:TNY'],
#  '8322fff2-98a6-45a8-b50f-70b803c3f779': ['CDEC:VRG',
#   'CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:TNY'],
#  '05ad4119-e0ab-43f7-9e96-de57026d72ab': ['CDEC:VRG',
#   'CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:TNY'],
#  'a831f8fa-bb62-4796-9355-4add622cfbb1': ['CDEC:VRG',
#   'CDEC:TUM',
#   'CDEC:PDS',
#   'CDEC:DAN',
#   'CDEC:HRS',
#   'CDEC:TNY'],
#  '6a134619-a23c-45b3-a11b-93a49dffe5eb': ['CDEC:VRG',
#   'CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:TNY'],
#  '830beea6-2ec4-45d5-bc90-e750f592311d': ['CDEC:VRG',
#   'CDEC:DAN',
#   'CDEC:TUM',
#   'CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:TNY'],
#  'b7b9112b-18a0-4c0f-b6eb-dfe8d2370eef': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL'],
#  '3fb0ce9a-1d03-4528-a807-4e1f141d0698': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL'],
#  'c6054f06-a96f-4ff7-86d6-4fd470c4eee1': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL'],
#  '4b41ea63-13e3-4b5c-8bfd-ce4d8268b9a0': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:WHW',
#   'CDEC:GNL',
#   'SNOTEL:771_CA_SNTL'],
#  'd19f732c-faad-4dc3-a4ad-aa0b08335d50': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:WHW',
#   'SNOTEL:575_CA_SNTL',
#   'SNOTEL:771_CA_SNTL'],
#  'a0db5220-4cd5-4bc6-906b-f499a42c6e56': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:LVT',
#   'CDEC:WHW',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM'],
#  'e745d1fe-44c6-42b6-ad0e-42adc1b0976f': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:VRG',
#   'CDEC:LVT',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM'],
#  '070a34e5-382b-4974-b73d-3281afcbe41b': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:VRG',
#   'CDEC:LVT',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM'],
#  'a3a99e81-dd5e-49cc-bc85-4080dabff904': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:VRG',
#   'CDEC:TUM',
#   'CDEC:TNY',
#   'CDEC:DAN'],
#  '02fa9f4d-a454-4e73-8aea-4d19c4ee3e37': ['CDEC:VRG',
#   'CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:TNY'],
#  '25a28ddb-49d5-4299-9912-5eb91a2a13d9': ['CDEC:VRG',
#   'CDEC:DAN',
#   'CDEC:TUM',
#   'CDEC:PDS',
#   'CDEC:TNY',
#   'CDEC:HRS'],
#  '599d38d8-8151-4a0c-af11-5bb368dfbc64': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'CDEC:DDM'],
#  '2db1bf68-6e69-4288-9dd2-caeb6c988ba7': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL'],
#  'be11c44f-ddbf-497c-9dcb-23fd89dabd65': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL'],
#  '5ed7489b-f6d4-4d10-be9b-3e4ae536b739': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:GNL',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL'],
#  '5f1cc685-3ea9-415b-b9f0-a90bfcb3d651': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'CDEC:GNL',
#   'SNOTEL:771_CA_SNTL'],
#  '35c675db-a706-4514-a643-2bdb898e28a5': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'CDEC:GNL',
#   'SNOTEL:771_CA_SNTL'],
#  '853ef5b7-5c7d-4bd8-8665-4c3f3f1f8927': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'CDEC:GNL',
#   'SNOTEL:771_CA_SNTL'],
#  '09fd1b30-96eb-4750-b79e-0fb8fad91ae4': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'SNOTEL:575_CA_SNTL',
#   'SNOTEL:771_CA_SNTL'],
#  'dc94887d-762b-4a91-9782-0dd1fe5065e7': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM'],
#  '317d4879-fa3a-49de-8ae1-01d7e24d852d': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM'],
#  '8c51449d-49f7-4bca-aa19-db9da748f229': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:VRG',
#   'CDEC:TUM',
#   'CDEC:TNY',
#   'CDEC:DAN'],
#  '0e6beb18-71f1-428b-b40d-e724ed030521': ['CDEC:VRG',
#   'CDEC:TUM',
#   'CDEC:PDS',
#   'CDEC:DAN',
#   'CDEC:HRS',
#   'CDEC:TNY'],
#  'dfe49840-a9fc-414f-a78f-f67874c7da8e': ['CDEC:VRG',
#   'CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:PDS',
#   'CDEC:TNY',
#   'CDEC:HRS'],
#  'ab60019d-a2f4-43a2-82e4-a9a1e0736605': ['CDEC:VRG',
#   'CDEC:DAN',
#   'CDEC:TUM',
#   'CDEC:TNY',
#   'CDEC:PDS',
#   'CDEC:HRS'],
#  '08cf0d1a-5f8e-4747-b919-b6a42745c806': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL'],
#  '17da8ab4-6dd8-481e-a025-7574765ef9b1': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'CDEC:GNL',
#   'SNOTEL:771_CA_SNTL'],
#  '0e5de065-6a81-4fb3-b32a-5b271b00c1eb': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'CDEC:GNL',
#   'SNOTEL:771_CA_SNTL'],
#  '0d0b9ccc-952f-4260-96c6-7a82df0966b5': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'SNOTEL:575_CA_SNTL',
#   'CDEC:LVM'],
#  '13eaaeed-0d7b-46b2-81cc-1d83ed7714ae': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'CDEC:TNY',
#   'SNOTEL:575_CA_SNTL'],
#  '39f8a634-fd5f-4810-8815-700962260433': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'CDEC:TNY',
#   'CDEC:TUM'],
#  'f9343a91-0125-4eff-b9d5-7aac99f41c1f': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:TNY',
#   'CDEC:LVT',
#   'CDEC:TUM'],
#  'b0e10cf9-7cfa-4fe4-85ec-3a4ba99fbd2f': ['CDEC:VRG',
#   'CDEC:PDS',
#   'CDEC:TUM',
#   'CDEC:HRS',
#   'CDEC:DAN',
#   'CDEC:TNY'],
#  '60a95a8b-997d-4e39-a0b8-bdf27d8e02a1': ['CDEC:VRG',
#   'CDEC:PDS',
#   'CDEC:TUM',
#   'CDEC:HRS',
#   'CDEC:DAN',
#   'CDEC:TNY'],
#  '15722dc1-05ef-4ac0-9b09-fae99f81466e': ['CDEC:VRG',
#   'CDEC:DAN',
#   'CDEC:TUM',
#   'CDEC:TNY',
#   'CDEC:PDS',
#   'CDEC:HRS'],
#  '5f6b3b3e-9e5b-4eb8-8f14-cf5d762c0a28': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL'],
#  '9e55c10d-a88a-49f9-8a22-7870b9dbfe8f': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL'],
#  '902f36cf-c916-4715-883f-e73ad2ab4cc9': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL'],
#  '8087fd95-fd6e-4934-87e2-464176fb16fb': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL'],
#  '26df6281-14f4-4623-b25e-54d2a39de7d0': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'CDEC:GNL',
#   'CDEC:TNY'],
#  '213529b8-f0a6-459c-9f1c-b5259e6c6643': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'CDEC:TNY',
#   'SNOTEL:575_CA_SNTL'],
#  '25023393-6764-441b-a50e-378f8944e63e': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'CDEC:TNY',
#   'SNOTEL:575_CA_SNTL'],
#  'dd27c71e-bda1-41d8-9671-7062bf8a04de': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:TNY',
#   'CDEC:LVT',
#   'CDEC:TUM'],
#  'da2a9bae-a5a5-4e85-8118-d91b9f4b223d': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:TNY',
#   'CDEC:LVT',
#   'CDEC:TUM'],
#  '9492cc60-a3b5-4d01-930a-de44503101f2': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:TNY',
#   'CDEC:TUM',
#   'CDEC:LVT'],
#  '2bf720eb-8af4-4ded-8a41-b9d8499e7d92': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:VRG',
#   'CDEC:TUM',
#   'CDEC:TNY',
#   'CDEC:WHW'],
#  '30c30871-dc12-42bc-8e92-cca0fcafeed0': ['CDEC:PDS',
#   'CDEC:VRG',
#   'CDEC:HRS',
#   'CDEC:TUM',
#   'CDEC:TNY',
#   'CDEC:DAN'],
#  'b58047d8-8674-410f-a166-4f909edb5d7d': ['CDEC:VRG',
#   'CDEC:PDS',
#   'CDEC:TUM',
#   'CDEC:HRS',
#   'CDEC:TNY',
#   'CDEC:DAN'],
#  '85c5e51d-1ed5-48d8-a670-02cb75cf64fd': ['CDEC:VRG',
#   'CDEC:DAN',
#   'CDEC:TUM',
#   'CDEC:TNY',
#   'CDEC:PDS',
#   'CDEC:HRS'],
#  '0d633c13-efc9-4292-8e27-c3e2b6b52184': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'CDEC:GIN'],
#  'e9268924-2b6a-4379-afc7-2c9c7a48b148': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'CDEC:GIN'],
#  '7b5ad5c1-5d68-4a4e-bf92-59a71e670eae': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL'],
#  '53e6a17b-5a80-439c-9cac-eed577638a4b': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'SNOTEL:771_CA_SNTL'],
#  '28ecafae-ef37-443d-9f93-5e5a7969154a': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'CDEC:TNY',
#   'CDEC:GNL'],
#  'f534c173-04ee-46e4-9acc-ea00199697be': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'CDEC:TNY',
#   'SNOTEL:575_CA_SNTL'],
#  '7680c487-33fa-4a36-8357-93a8a4e9d42c': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:TNY',
#   'CDEC:TUM',
#   'CDEC:LVT'],
#  '144d8c26-082f-4e97-b8ec-4ed8c3200d45': ['CDEC:VRG',
#   'CDEC:PDS',
#   'CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:TNY',
#   'CDEC:HRS'],
#  'edfad8c2-1966-48a6-a1fe-c93a73d9fe26': ['CDEC:VRG',
#   'CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:PDS',
#   'CDEC:TNY',
#   'CDEC:HRS'],
#  '0ddd4f0b-cdf5-486c-90ef-477c546b7776': ['CDEC:VRG',
#   'CDEC:DAN',
#   'CDEC:TUM',
#   'CDEC:TNY',
#   'CDEC:PDS',
#   'CDEC:HRS'],
#  '3b494042-8171-4a7a-b1f2-c8e72319a87e': ['CDEC:VRG',
#   'CDEC:DAN',
#   'CDEC:TUM',
#   'CDEC:TNY',
#   'CDEC:PDS',
#   'CDEC:HRS'],
#  '855f8b6d-33bd-4ac1-a8c5-0ac683c70b28': ['CDEC:VRG',
#   'CDEC:DAN',
#   'CDEC:TUM',
#   'CDEC:TNY',
#   'CDEC:PDS',
#   'CDEC:GEM'],
#  '156449af-2ef3-4659-8311-155137cb49d4': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'CDEC:GIN'],
#  '4e74f751-78f4-4f32-8829-3d7e83cd70a4': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'CDEC:GIN'],
#  '4e1cd817-2687-4e8d-b32c-cd51be8497d3': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'CDEC:TNY'],
#  '5ed37147-8fcf-4c85-9805-b07523fdd6be': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'CDEC:TNY'],
#  '2da967f4-4cc5-4a98-bc13-916a6deece8f': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:LVT',
#   'CDEC:TNY',
#   'CDEC:GNL'],
#  'f7aca1f1-c70b-4313-bc9b-52a975a83929': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:TNY',
#   'CDEC:LVT',
#   'CDEC:GNL'],
#  '17c0748e-6390-4d19-bae8-8b659ac49318': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:TNY',
#   'CDEC:LVT',
#   'CDEC:TUM'],
#  'd97eff2e-873a-4f83-9a37-085629b35bec': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:TNY',
#   'CDEC:TUM',
#   'CDEC:VRG'],
#  '4f5110ce-1d82-466f-95ce-d70f039b88cb': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:TNY',
#   'CDEC:TUM',
#   'CDEC:VRG'],
#  'afcba0bf-b6e4-4748-8230-228fe42f4a33': ['CDEC:PDS',
#   'CDEC:VRG',
#   'CDEC:TUM',
#   'CDEC:TNY',
#   'CDEC:HRS',
#   'CDEC:DAN'],
#  '797be1b8-d9c4-4f9c-a62f-27ac952b17f5': ['CDEC:VRG',
#   'CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:TNY',
#   'CDEC:PDS',
#   'CDEC:HRS'],
#  '9ca51126-fec9-4fdb-99c3-952a7b88ac12': ['CDEC:VRG',
#   'CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:TNY',
#   'CDEC:PDS',
#   'CDEC:HRS'],
#  '8441d405-f9f4-45a8-a611-9416eb05e1a0': ['CDEC:VRG',
#   'CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:TNY',
#   'CDEC:PDS',
#   'CDEC:HRS'],
#  '1540e98a-ac6f-4858-bb20-24be795c43db': ['CDEC:VRG',
#   'CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:TNY',
#   'CDEC:PDS',
#   'CDEC:HRS'],
#  '7ab52073-532e-48bf-9360-ad9827d27e12': ['CDEC:VRG',
#   'CDEC:DAN',
#   'CDEC:TUM',
#   'CDEC:TNY',
#   'CDEC:PDS',
#   'CDEC:HRS'],
#  '95f905fd-29eb-43ad-9a6b-1ddc23018c56': ['CDEC:VRG',
#   'CDEC:DAN',
#   'CDEC:TUM',
#   'CDEC:TNY',
#   'CDEC:GEM',
#   'CDEC:PDS'],
#  '73ef4443-2d42-47d1-ae07-e803c25e0ca5': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:GNL',
#   'CDEC:GIN',
#   'CDEC:LVT'],
#  '32b41bf0-1c8c-4cad-9c09-31ed7fcf5f95': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:GNL',
#   'CDEC:GIN',
#   'CDEC:LVT'],
#  '9e2f6c75-2e9e-4c58-a917-190d8b3c41de': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:GNL',
#   'CDEC:LVT',
#   'CDEC:GIN'],
#  '351d475b-25d2-44c8-beb4-cf3efa6e3481': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:WHW',
#   'CDEC:TNY',
#   'CDEC:LVT',
#   'CDEC:GNL'],
#  '20a59526-dd57-4690-9734-e386dfd2afa4': ['CDEC:PDS',
#   'CDEC:HRS',
#   'CDEC:TNY',
#   'CDEC:TUM',
#   'CDEC:WHW',
#   'CDEC:VRG'],
#  '92ae589a-f0c3-417b-8664-7f782e88d59f': ['CDEC:PDS',
#   'CDEC:TUM',
#   'CDEC:TNY',
#   'CDEC:VRG',
#   'CDEC:HRS',
#   'CDEC:DAN'],
#  '126443e4-cce4-4a4b-8400-d5d23d41864e': ['CDEC:PDS',
#   'CDEC:TUM',
#   'CDEC:VRG',
#   'CDEC:TNY',
#   'CDEC:DAN',
#   'CDEC:HRS'],
#  '1805eb6a-b396-465a-99bb-998e30feff3d': ['CDEC:VRG',
#   'CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:TNY',
#   'CDEC:PDS',
#   'CDEC:HRS'],
#  '5d96761d-75f2-4922-b223-d249104a2689': ['CDEC:VRG',
#   'CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:TNY',
#   'CDEC:PDS',
#   'CDEC:HRS'],
#  '115b330e-1f46-419a-badb-5713970eb282': ['CDEC:VRG',
#   'CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:TNY',
#   'CDEC:PDS',
#   'CDEC:HRS'],
#  
['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:HRS',
#   'CDEC:GIN',
#   'CDEC:GNL',
#   'CDEC:TNY'],
#  '4bf01cf1-b330-4ea2-921e-183fe9c13e8c': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:HRS',
#   'CDEC:GIN',
#   'CDEC:GNL',
#   'CDEC:TNY'],
#  'bae8c8d8-7a2d-49b5-8b22-98ade39a6829': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:HRS',
#   'CDEC:GIN',
#   'CDEC:TNY',
#   'CDEC:GNL'],
#  'bf65c68d-0352-4e15-84a2-ac5ce44dd389': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:HRS',
#   'CDEC:TNY',
#   'CDEC:GIN',
#   'CDEC:TUM'],
#  '8e868c36-2335-43e4-9e9d-c9622ab033b3': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:HRS',
#   'CDEC:TNY',
#   'CDEC:TUM',
#   'CDEC:GIN'],
#  '16a2b951-62e7-47d9-b854-762163a19daa': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:TNY',
#   'CDEC:HRS',
#   'CDEC:TUM',
#   'CDEC:DAN'],
#  'b0ab87fc-17a3-4a71-a748-f298b898396f': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:TNY',
#   'CDEC:HRS',
#   'CDEC:TUM',
#   'CDEC:DAN'],
#  '9c60a2ce-ee7d-4d32-8a0b-fda06ac147ce': ['CDEC:TNY',
#   'CDEC:TUM',
#   'CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:DAN',
#   'CDEC:VRG'],
#  '641e5209-126f-41b6-8e87-0bf3f0fc8d04': ['CDEC:TUM',
#   'CDEC:TNY',
#   'CDEC:PDS',
#   'CDEC:DAN',
#   'CDEC:WHW',
#   'CDEC:VRG'],
#  'dcbb9bb1-03f0-45d4-8e8a-ab7c17a8e125': ['CDEC:TUM',
#   'CDEC:TNY',
#   'CDEC:DAN',
#   'CDEC:VRG',
#   'CDEC:PDS',
#   'CDEC:WHW'],
#  '947423f3-12e0-4e64-9abf-17c4a8291925': ['CDEC:TUM',
#   'CDEC:TNY',
#   'CDEC:DAN',
#   'CDEC:VRG',
#   'CDEC:PDS',
#   'CDEC:WHW'],
#  'e89064ca-25f2-4a0f-b3a1-2b6c1d56e878': ['CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:VRG',
#   'CDEC:TNY',
#   'CDEC:PDS',
#   'CDEC:GEM'],
#  'e6e34b21-47ed-40be-a0d7-86c63db2d954': ['CDEC:DAN',
#   'CDEC:TUM',
#   'CDEC:VRG',
#   'CDEC:TNY',
#   'CDEC:GEM',
#   'CDEC:PDS'],
#  '0f8fa17c-fe17-4232-8d1b-a176c59d4927': ['CDEC:DAN',
#   'CDEC:TUM',
#   'CDEC:VRG',
#   'CDEC:TNY',
#   'CDEC:GEM',
#   'CDEC:PDS'],
#  '380d8e65-5371-43c4-aa86-2ae5712510a8': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:HRS',
#   'CDEC:GIN',
#   'CDEC:GNL',
#   'CDEC:TNY'],
#  'b30f3b80-7664-4125-8c74-e07463a1f8df': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:HRS',
#   'CDEC:GIN',
#   'CDEC:GNL',
#   'CDEC:TNY'],
#  '3bf1ada0-7c8f-452e-b910-a478a8b9d4b6': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:HRS',
#   'CDEC:GIN',
#   'CDEC:TNY',
#   'CDEC:GNL'],
#  '731d8eb6-0d7a-457c-a0bf-131bc9004f6b': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:HRS',
#   'CDEC:GIN',
#   'CDEC:TNY',
#   'CDEC:GNL'],
#  'b06a6238-fc38-48f6-8560-e2c0b88bcff8': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:HRS',
#   'CDEC:GIN',
#   'CDEC:TNY',
#   'CDEC:TUM'],
#  'ee3cb642-97a9-47d2-a405-feb0ee6df20b': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:HRS',
#   'CDEC:TNY',
#   'CDEC:GIN',
#   'CDEC:TUM'],
#  'ad3634d1-e5bf-4fc9-8b55-4e928dc36c52': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:HRS',
#   'CDEC:TNY',
#   'CDEC:GIN',
#   'CDEC:TUM'],
#  'c514cef8-ebb5-4b1f-8026-cd71bf3981c8': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:HRS',
#   'CDEC:TNY',
#   'CDEC:GIN',
#   'CDEC:TUM'],
#  '52e77cdb-30a9-4875-b3a5-d575386e148e': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:TNY',
#   'CDEC:HRS',
#   'CDEC:TUM',
#   'CDEC:GIN'],
#  '45338457-d212-475a-8406-3f28b5bbded1': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:TNY',
#   'CDEC:HRS',
#   'CDEC:TUM',
#   'CDEC:GIN'],
#  '7b7a5861-0f59-4efb-b07c-f03b7b85d8c9': ['CDEC:PDS',
#   'CDEC:TNY',
#   'CDEC:WHW',
#   'CDEC:TUM',
#   'CDEC:HRS',
#   'CDEC:DAN'],
#  '20f576c5-1846-4aec-8b36-e174e931df19': ['CDEC:TNY',
#   'CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:HRS'],
#  'caa791e6-0d91-43d9-827c-6984513e5daf': ['CDEC:TNY',
#   'CDEC:PDS',
#   'CDEC:TUM',
#   'CDEC:WHW',
#   'CDEC:DAN',
#   'CDEC:HRS'],
#  '4de49f5a-fb30-45f0-8270-9c514fe16dfb': ['CDEC:TNY',
#   'CDEC:TUM',
#   'CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:DAN',
#   'CDEC:VRG'],
#  '2b95a45e-c96e-4738-8a19-a8c71f6f79c9': ['CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:TNY',
#   'CDEC:VRG',
#   'CDEC:PDS',
#   'CDEC:WHW'],
#  'b5830e7d-e54f-422e-b1a5-4084d82aacc3': ['CDEC:DAN',
#   'CDEC:TUM',
#   'CDEC:VRG',
#   'CDEC:TNY',
#   'CDEC:GEM',
#   'CDEC:AGP'],
#  'd04201a9-4ee4-40d8-a060-6e733933a037': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:HRS',
#   'CDEC:GIN',
#   'CDEC:TNY',
#   'CDEC:GNL'],
#  '154fd2a7-b386-4df4-a9ab-d8f15fcc387c': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:HRS',
#   'CDEC:TNY',
#   'CDEC:GIN',
#   'CDEC:TUM'],
#  '9a4953c7-120b-4240-8812-5c6ee9042f2f': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:HRS',
#   'CDEC:TNY',
#   'CDEC:GIN',
#   'CDEC:TUM'],
#  'c8b9c3e1-4f51-4326-a451-4b0633986ad1': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:TNY',
#   'CDEC:HRS',
#   'CDEC:TUM',
#   'CDEC:GIN'],
#  'f3ddd5e2-c724-4b24-8097-85f1ef305be2': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:TNY',
#   'CDEC:HRS',
#   'CDEC:TUM',
#   'CDEC:GIN'],
#  '73228db9-e63a-4430-9229-05bf352c874f': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:TNY',
#   'CDEC:TUM',
#   'CDEC:HRS',
#   'CDEC:DAN'],
#  '107f60e5-189f-4e89-91b3-8657326fe178': ['CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:TNY',
#   'CDEC:TUM',
#   'CDEC:HRS',
#   'CDEC:DAN'],
#  'b8acddf4-f26e-4cf3-af60-67f0c8a3a86d': ['CDEC:TNY',
#   'CDEC:TUM',
#   'CDEC:PDS',
#   'CDEC:WHW',
#   'CDEC:DAN',
#   'CDEC:VRG'],
#  '11ffac43-24c4-4892-8d56-8ba6c6d6d6d1': ['CDEC:TUM',
#   'CDEC:TNY',
#   'CDEC:DAN',
#   'CDEC:VRG',
#   'CDEC:WHW',
#   'CDEC:PDS'],
#  'f3d389ca-e43f-4c23-b4ca-a0ac3f2f49af': ['CDEC:TUM',
#   'CDEC:DAN',
#   'CDEC:TNY',
#   'CDEC

#   'CDEC:DAN',
#   'CDEC:GEM'],
#  '53d89680-b908-428e-965b-882d881e058a': ['CDEC:TNY',
#   'CDEC:TUM',
#   'CDEC:WHW',
#   'CDEC:GIN',
#   'CDEC:DAN',
#   'CDEC:GEM'],
#  '0bd2b156-8c6c-4b11-bf50-075891a572b9': ['CDEC:TNY',
#   'CDEC:TUM',
#   'CDEC:WHW',
#   'CDEC:DAN',
#   'CDEC:GEM',
#   'CDEC:GIN'],
#  'bba1bf1b-94dd-4b3e-bbce-65a0e6d12a48': ['CDEC:TNY',
#   'CDEC:TUM',
#   'CDEC:GEM',
#   'CDEC:DAN',
#   'CDEC:AGP',
#   'CDEC:WHW'],
#  'a922756d-9e3e-4456-991a-4346343c5ca2': ['CDEC:TNY',
#   'CDEC:TUM',
#   'CDEC:GEM',
#   'CDEC:AGP',
#   'CDEC:DAN',
#   'CDEC:GRM']}

# %%
import os
import pandas as pd

folder_path = r"C:\Users\VISH NU\NSM_EvaluationTool\Standardized-Snow-Water-Equivalent-Evaluation-Tool\SSWEET\Processed_Data\SWE_csv"
dataframes = []

for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        file_path = os.path.join(folder_path, filename)

        df = pd.read_csv(file_path)

        if "data" in df.columns:
            df = df.drop(columns=["data"])

        dataframes.append(df)

merged_df = pd.concat(dataframes, ignore_index=True)
merged_df = merged_df.drop_duplicates(subset=["y", "x"])

# Save the final DataFrame to a new CSV file
output_file = r"C:\Users\VISH NU\NSM_EvaluationTool\Standardized-Snow-Water-Equivalent-Evaluation-Tool\SSWEET\sierras_metadata.csv"
merged_df.to_csv(output_file, index=False)

# %%
Geospatial_df = pd.read_csv(r"C:\Users\VISH NU\NSM_EvaluationTool\Example folder\Prediction_Sierras_Metadata.csv")
Geospatial_df.head(10)
# Out:
#    Unnamed: 0                                         cell_id  BR_Coord_Long  \
# 0           0  37_cell_-119.93413483662393_36.152585292758516      36.152585
# 1           1   37_cell_-119.93413483662393_36.15331063299072      36.153311
# 2           2   37_cell_-119.93413483662393_36.15403596651389      36.154036
# 3           3  37_cell_-119.93413483662393_36.154761293327994      36.154761
# 4           4   37_cell_-119.93413483662393_36.15548661343295      36.155487
# 5           5   37_cell_-119.93413483662393_36.15621192682872      36.156212
# 6           6   37_cell_-119.93413483662393_36.15693723351524      36.156937
# 7           7  37_cell_-119.93413483662393_36.157662533492456      36.157663
# 8           8   37_cell_-119.93413483662393_36.15838782676033      36.158388
# 9           9    37_cell_-119.93413483662393_36.1591131133188      36.159113
#
#    BR_Coord_Lat  UR_Coord_Long  UR_Coord_Lat  UL_Coord_Long  UL_Coord_Lat  \
# 0   -119.934135      36.153311   -119.934135      36.153311   -119.933237
# 1   -119.934135      36.154036   -119.934135      36.154036   -119.933237
# 2   -119.934135      36.154761   -119.934135      36.154761   -119.933237
# 3   -119.934135      36.155487   -119.934135      36.155487   -119.933237
# 4   -119.934135      36.156212   -119.934135      36.156212   -119.933237
# 5   -119.934135      36.156937   -119.934135      36.156937   -119.933237
# 6   -119.934135      36.157663   -119.934135      36.157663   -119.933237
# 7   -119.934135      36.158388   -119.934135      36.158388   -119.933237
# 8   -119.934135      36.159113   -119.934135      36.159113   -119.933237
# 9   -119.934135      36.159838   -119.934135      36.159838   -119.933237
#
#    BL_Coord_Long  BL_Coord_Lat  \
# 0      36.152585   -119.933237
# 1      36.153311   -119.933237
# 2      36.154036   -119.933237
# 3      36.154761   -119.933237
# 4      36.155487   -119.933237
# 5      36.156212   -119.933237
# 6      36.156937   -119.933237
# 7      36.157663   -119.933237
# 8      36.158388   -119.933237
# 9      36.159113   -119.933237
#
#                                             geometry
# 0  POLYGON ((36.152585292758516 -119.934134836623...
# 1  POLYGON ((36.15331063299072 -119.9341348366239...
# 2  POLYGON ((36.15403596651389 -119.9341348366239...
# 3  POLYGON ((36.154761293327994 -119.934134836623...
# 4  POLYGON ((36.15548661343295 -119.9341348366239...
# 5  POLYGON ((36.15621192682872 -119.9341348366239...
# 6  POLYGON ((36.15693723351524 -119.9341348366239...
# 7  POLYGON ((36.157662533492456 -119.934134836623...
# 8  POLYGON ((36.15838782676033 -119.9341348366239...
# 9  POLYGON ((36.1591131133188 -119.93413483662393...

# %%
#bounding_box = (-120.3763448720203, 36.29256774541929, -118.292253412863, 38.994985247736324)

# %%
import math
from pyproj import CRS, Transformer
from pystac_client import Client
import planetary_computer
import gdal
from gdal import gdalconst
import pandas as pd

# Function to extract terrain data for the given latitudes and longitudes
def extract_terrain_data(metadata_df, bounding_box):
    
    min_x, min_y = bounding_box[0]
    max_x, max_y = bounding_box[1]
    
    BLelev_L = []
    BLslope_L = []
    BLaspect_L = []
    
    client = Client.open(
            "https://planetarycomputer.microsoft.com/api/stac/v1",
            ignore_conformance=True,
        )

    search = client.search(
                    collections=["cop-dem-glo-90"],
                    intersects = {
                            "type": "Polygon",
                            "coordinates": [[
                            [min_x, min_y],
                            [max_x, min_y],
                            [max_x, max_y],
                            [min_x, max_y],
                            [min_x, min_y]  
                        ]]})

    tiles = list(search.items())

    regions = []

    print("Retrieving Copernicus 90m DEM tiles")
    for i in tqdm(range(0, len(tiles))):
        row = [i, tiles[i].id]
        regions.append(row)
    regions = pd.DataFrame(columns = ['sliceID', 'tileID'], data = regions)
    regions = regions.set_index(regions['tileID'])
    del regions['tileID']

    print("Interpolating Grid Cell Spatial Features")

    for i in tqdm(range(len(metadata_df))):
        
        lat = metadata_df.iloc[i]['BR_Coord_Lat']
        lon = metadata_df.iloc[i]['BR_Coord_Long']

        tile_id = 'Copernicus_DSM_COG_30_N' + str(math.floor(lon)) + '_00_W' + str(math.ceil(abs(lat))) + '_00_DEM'
        index_id = regions.loc[tile_id]['sliceID']

        signed_asset = planetary_computer.sign(tiles[index_id].assets["data"])
        elevation = rxr.open_rasterio(signed_asset.href)

        slope = elevation.copy()
        aspect = elevation.copy()

        transformer = Transformer.from_crs("EPSG:4326", elevation.rio.crs, always_xy=True)
        xx, yy = transformer.transform(lon, lat)

        tilearray = np.around(elevation.values[0]).astype(int)

        geo = (math.floor(float(lon)), 90, 0.0, math.ceil(float(lat)), 0.0, -90)
        
        """
        tilearray = rd.rdarray(tilearray, no_data=-9999)
        tilearray.projection = 'EPSG:4326'
        tilearray.geotransform = geo

        slope_arr = rd.TerrainAttribute(tilearray, attrib='slope_degrees')
        aspect_arr = rd.TerrainAttribute(tilearray, attrib='aspect')
        """
        no_data_value = -9999
        driver = gdal.GetDriverByName('MEM')
        temp_ds = driver.Create('', tilearray.shape[1], tilearray.shape[0], 1, gdalconst.GDT_Float32)

        # Write data to the in-memory raster
        temp_ds.GetRasterBand(1).WriteArray(tilearray)
        temp_ds.GetRasterBand(1).SetNoDataValue(no_data_value)

        # Set projection and geotransform
        temp_ds.SetProjection('EPSG:4326')
        temp_ds.SetGeoTransform(geo)

        # Read data back as a numpy array
        tilearray_np = temp_ds.GetRasterBand(1).ReadAsArray()

        # Compute slope and aspect using numpy gradient
        slope_arr, aspect_arr = np.gradient(tilearray_np)

        # Convert radians to degrees for aspect
        aspect_arr = np.rad2deg(np.arctan2(aspect_arr[0], aspect_arr[1]))

        slope.values[0] = slope_arr
        aspect.values[0] = aspect_arr

        elev = round(elevation.sel(x=xx, y=yy, method="nearest").values[0])
        slop = round(slope.sel(x=xx, y=yy, method="nearest").values[0])
        asp = round(aspect.sel(x=xx, y=yy, method="nearest").values[0])

        BLelev_L.append(elev)
        BLslope_L.append(slop)
        BLaspect_L.append(asp)

    metadata_df['Elevation_m'] = BLelev_L
    metadata_df['Slope_Deg'] = BLslope_L
    metadata_df['Aspect_L'] = BLaspect_L
    

Geospatial_df = pd.read_csv(r"C:\Users\VISH NU\NSM_EvaluationTool\Example folder\Prediction_Sierras_Metadata.csv")
bounding_box = ((-120.3763448720203, 36.29256774541929), (-118.292253412863, 38.994985247736324))    
    
# Call the function with the small metadata DataFrame
extract_terrain_data(Geospatial_df, bounding_box)

# Display the results
Geospatial_df.head(10)
# Out:
# C:\Users\VISH NU\anaconda3\envs\NSM\lib\site-packages\pystac_client\client.py:176: FutureWarning: The `ignore_conformance` option is deprecated and will be removed in the next major release. Instead use `set_conforms_to` or `add_conforms_to` to control behavior.
#   warnings.warn(
# Retrieving Copernicus 90m DEM tiles
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<?, ?it/s]
# Interpolating Grid Cell Spatial Features
#   0%|                                                                       | 1859/5201957 [18:27<860:46:35,  1.68it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 120
#     117 bounding_box = ((-120.3763448720203, 36.29256774541929), (-118.292253412863, 38.994985247736324))
#     119 # Call the function with the small metadata DataFrame
# --> 120 extract_terrain_data(Geospatial_df, bounding_box)
#     122 # Display the results
#     123 Geospatial_df.head(10)
#
# Cell In[2], line 67, in extract_terrain_data(metadata_df, bounding_box)
#      64 transformer = Transformer.from_crs("EPSG:4326", elevation.rio.crs, always_xy=True)
#      65 xx, yy = transformer.transform(lon, lat)
# ---> 67 tilearray = np.around(elevation.values[0]).astype(int)
#      69 geo = (math.floor(float(lon)), 90, 0.0, math.ceil(float(lat)), 0.0, -90)
#      71 """
#      72 tilearray = rd.rdarray(tilearray, no_data=-9999)
#      73 tilearray.projection = 'EPSG:4326'
#    (...)
#      77 aspect_arr = rd.TerrainAttribute(tilearray, attrib='aspect')
#      78 """
#
# File <__array_function__ internals>:180, in around(*args, **kwargs)
#
# File ~\anaconda3\envs\NSM\lib\site-packages\numpy\core\fromnumeric.py:3348, in around(a, decimals, out)
#    3257 @array_function_dispatch(_around_dispatcher)
#    3258 def around(a, decimals=0, out=None):
#    3259     """
#    3260     Evenly round to the given number of decimals.
#    3261
#    (...)
#    3346
#    3347     """
# -> 3348     return _wrapfunc(a, 'round', decimals=decimals, out=out)
#
# File ~\anaconda3\envs\NSM\lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %%
import geopandas as gpd
from shapely.geometry import Polygon
from pyproj import Proj, transform, Transformer

def calculate_UTM_zone(Lat, LongTemp):
    ZoneNumber = int((LongTemp + 180) / 6) + 1

    if 56.0 <= Lat < 64.0 and 3.0 <= LongTemp < 12.0:
        ZoneNumber = 32
    
    # Special zones for Svalbard
    if 72.0 <= Lat < 84.0:
        if 0.0 <= LongTemp < 9.0:
            ZoneNumber = 31
        elif 9.0 <= LongTemp < 21.0:
            ZoneNumber = 33
        elif 21.0 <= LongTemp < 33.0:
            ZoneNumber = 35
        elif 33.0 <= LongTemp < 42.0:
            ZoneNumber = 37

    return ZoneNumber

def generate_grid_cells(bbox, resolution):

    minx, miny, maxx, maxy = bbox

    # Transform the bounding box coordinates to Web Mercator
    src_crs = CRS('EPSG:4326')
    target_crs = CRS('EPSG:3857')
    transformer = Transformer.from_crs(src_crs, target_crs, always_xy=True)
    minx, miny = transformer.transform(minx, miny)
    maxx, maxy = transformer.transform(maxx, maxy)

    # Calculate the number of cells in x and y directions
    num_cells_x = int((maxx - minx) / resolution)
    num_cells_y = int((maxy - miny) / resolution)

    # Generate latitude and longitude ranges
    lon_range = [minx + i * resolution for i in range(num_cells_x + 1)]
    lat_range = [miny + i * resolution for i in range(num_cells_y + 1)]

    transformer_reverse = Transformer.from_crs(target_crs, src_crs)

    # Create grid cells
    cells = []
    for i in range(num_cells_x):
        for j in range(num_cells_y):
            
            br_coord = (lon_range[i], lat_range[j])
            ur_coord = (lon_range[i + 1], lat_range[j + 1])
            ul_coord = (lon_range[i], lat_range[j + 1])
            bl_coord = (lon_range[i + 1], lat_range[j])
            
            # Calculate UTM zone for the cell
            utm_zone = calculate_UTM_zone(br_coord[1], br_coord[0])
            
            cell_id = f"{utm_zone}_cell_{br_coord[1]}_{br_coord[0]}"

            br_coord = transformer_reverse.transform(br_coord[0], br_coord[1])
            ur_coord = transformer_reverse.transform(ur_coord[0], ur_coord[1])
            ul_coord = transformer_reverse.transform(ul_coord[0], ul_coord[1])
            bl_coord = transformer_reverse.transform(bl_coord[0], bl_coord[1])

            geometry = Polygon([br_coord, ur_coord, ul_coord, bl_coord])

            cell = {
                "cell_id": cell_id,
                "geometry": geometry,
                "BR_Coord_Long": br_coord[0],
                "BR_Coord_Lat": br_coord[1],
                "UR_Coord_Long": ur_coord[0],
                "UR_Coord_Lat": ur_coord[1],
                "UL_Coord_Long": ul_coord[0],
                "UL_Coord_Lat": ul_coord[1],
                "BL_Coord_Long": bl_coord[0],
                "BL_Coord_Lat": bl_coord[1],
                "UTM_Zone": utm_zone,
            }

            cells.append(cell)

    # Create a GeoDataFrame from the cells
    grid_cells = gpd.GeoDataFrame(cells, geometry="geometry")

    return grid_cells

# Example usage:
bbox = [-120.3763448720203, 36.29256774541929, -118.292253412863, 38.994985247736324]
resolution = 100
df = generate_grid_cells(bbox, resolution)

# Print the resulting GeoDataFrame
print(df.head())
